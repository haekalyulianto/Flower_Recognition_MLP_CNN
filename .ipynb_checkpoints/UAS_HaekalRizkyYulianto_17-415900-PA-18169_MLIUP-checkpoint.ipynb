# %% [markdown]
# **ML Final Exam**
#
# **Name : Haekal Rizky Yulianto**
#
# **NIM  : 17/415900/PA/18169**

# %% [markdown]
# # Mulilayer Perceptron

# %% [markdown]
# Import required library

# %%
import numpy as np
import matplotlib.pyplot as plt
import random
from random import randint
import cv2

# %% [markdown]
# ## Data preparation

# %% [markdown]
# Check directory

# %%
import os
print(os.listdir("/Users/Haekal/Documents/ML/input"))
print(os.listdir("/Users/Haekal/Documents/ML/input/flowers/flowers"))
# Out:
# ['.DS_Store', 'flowers']
# ['.DS_Store', 'daisy', 'rose', 'tulip', 'dandelion', 'sunflower']

# %% [markdown]
# Read Image

# %%
trainLabels = [] # Image label array
data = [] # Image data array

size = 320, 240 # Resize image

def readImages(flowerPath, folder):
    
    imagePaths = []
    for file in os.listdir(flowerPath):
        if file.endswith("jpg"):
            imagePaths.append(flowerPath + file)
            trainLabels.append(folder)
            img = cv2.imread((flowerPath + file), 0)
            im = cv2.resize(img, size)
            data.append(im)            
            
    return imagePaths

# %%
daisy_path = "/Users/Haekal/Documents/ML/input/flowers/flowers/daisy/"
rose_path = "/Users/Haekal/Documents/ML/input/flowers/flowers/rose/"
tulip_path = "/Users/Haekal/Documents/ML/input/flowers/flowers/tulip/"

# %% [markdown]
# Show Image

# %%
def showImage(imgPath):
    img = cv2.imread(imgPath)
    plt.imshow(img, cmap = 'gray', interpolation = 'bicubic')
    plt.axis('off')
    plt.show()

# %%
daisyPaths = readImages(daisy_path, 'daisy')
rosePaths = readImages(rose_path, 'rose')
tulipPaths = readImages(tulip_path, 'tulip')

showImage(daisyPaths[4]) # Example of daisy image in index 4
showImage(rosePaths[4]) # Example of rose image in index 4
showImage(tulipPaths[4]) # Example of tulip image in index 4

# %% [markdown]
# ## Data preprocessing

# %% [markdown]
# Normalize image data

# %%
X = np.array(data)
X = X.astype('float32') / 255.0

# %% [markdown]
# One hot encoding for target variable

# %%
raw_data = {'category': trainLabels}

# %%
import pandas as pd
df = pd.DataFrame(raw_data, columns = ['category'])
df
# Out:
#     category
# 0      daisy
# 1      daisy
# 2      daisy
# 3      daisy
# 4      daisy
# ..       ...
# 295    tulip
# 296    tulip
# 297    tulip
# 298    tulip
# 299    tulip
#
# [300 rows x 1 columns]

# %%
def to_numeric(x):
    if x == 'daisy':
        return '0'
    if x == 'rose':
        return '1'
    if x == 'tulip':
        return '2'

# %%
df['cat'] = df['category'].apply(to_numeric)

# %%
y = pd.get_dummies(df.cat, prefix='C')
y
# Out:
#      C_0  C_1  C_2
# 0      1    0    0
# 1      1    0    0
# 2      1    0    0
# 3      1    0    0
# 4      1    0    0
# ..   ...  ...  ...
# 295    0    0    1
# 296    0    0    1
# 297    0    0    1
# 298    0    0    1
# 299    0    0    1
#
# [300 rows x 3 columns]

# %% [markdown]
# Transform into 2D shape

# %%
print(X.shape)
print(y.shape)
# Out:
# (300, 240, 320)
# (300, 3)

# %%
y = np.array(y)

# %%
X = X.reshape(X.shape[0], X.shape[1] * X.shape[2])
Y = y

# %%
print(X.shape)
print(Y.shape)
# Out:
# (300, 76800)
# (300, 3)

# %% [markdown]
# Split the data for training and testing

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state = 42)
numberOfTrain = X_train.shape[0]
numberOfTest = X_test.shape[0]

print('Train size : ', X_train.shape[0], 'Test size : ', X_test.shape[0])
# Out:
# Train size :  240 Test size :  60

# %% [markdown]
# Transpose the data

# %%
X_train = X_train.T
X_test = X_test.T
Y_train = Y_train.T
Y_test = Y_test.T

# %%
print(X_train.shape)
print(Y_train.shape)
# Out:
# (76800, 240)
# (3, 240)

# %% [markdown]
# ## Model training

# %% [markdown]
# Declare required functions for multilayer perceptron

# %%
def sigmoid(z):
    s = 1. / (1. + np.exp(-z))
    return s

def compute_loss(Y, Y_hat):

    L_sum = np.sum(np.multiply(Y, np.log(Y_hat)))
    m = Y.shape[1]
    L = -(1./m) * L_sum

    return L

def feed_forward(X, params):

    cache = {}

    cache["Z1"] = np.matmul(params["W1"], X) + params["b1"]
    cache["A1"] = sigmoid(cache["Z1"]) # Sigmoid activation function
    cache["Z2"] = np.matmul(params["W2"], cache["A1"]) + params["b2"]
    cache["A2"] = np.exp(cache["Z2"]) / np.sum(np.exp(cache["Z2"]), axis=0) # Softmax activation function

    return cache

def back_propagate(X, Y, params, cache):

    dZ2 = cache["A2"] - Y
    dW2 = (1./m_batch) * np.matmul(dZ2, cache["A1"].T)
    db2 = (1./m_batch) * np.sum(dZ2, axis=1, keepdims=True)

    dA1 = np.matmul(params["W2"].T, dZ2)
    dZ1 = dA1 * sigmoid(cache["Z1"]) * (1 - sigmoid(cache["Z1"]))
    dW1 = (1./m_batch) * np.matmul(dZ1, X.T)
    db1 = (1./m_batch) * np.sum(dZ1, axis=1, keepdims=True)

    grads = {"dW1": dW1, "db1": db1, "dW2": dW2, "db2": db2}

    return grads

# %% [markdown]
# Declare function to calculate accuracy

# %%
def accuracy_metric(actual, predicted):
    correct = 0
    for i in range(len(actual)):
        if actual[i] == predicted[i]:
            correct += 1
    return correct / float(len(actual)) * 100.0

# %% [markdown]
# Training and testing

# %%
np.random.seed(42) # Random seed for reproducibility
m = numberOfTrain # Number of training data

# Hyperparameters
n_x = X_train.shape[0] # Number of neuron in input layer = 320 X 240 = 76800
n_h = 64 # Number of neuron in hidden layer
num_class = 3 # Number of class
learning_rate = 0.1
beta = 0.5
batch_size = 128
batches = -(-m // batch_size)

# Initialization
params = { "W1": np.random.randn(n_h, n_x) * np.sqrt(1. / n_x),
           "b1": np.zeros((n_h, 1)) * np.sqrt(1. / n_x),
           "W2": np.random.randn(num_class, n_h) * np.sqrt(1. / n_h),
           "b2": np.zeros((num_class, 1)) * np.sqrt(1. / n_h) }

V_dW1 = np.zeros(params["W1"].shape)
V_db1 = np.zeros(params["b1"].shape)
V_dW2 = np.zeros(params["W2"].shape)
V_db2 = np.zeros(params["b2"].shape)

ep = 300 # Number of epoch 
epoch = list(range(1,ep+1))
train_history = []
test_history = []
train_accuracy = []
test_accuracy = []

# Training
for i in range(ep):

    for j in range (int(batches)):
        
        begin = j * batch_size
        end = min(begin + batch_size, X_train.shape[1] - 1)
        m_batch = end - begin

        cache = feed_forward(X_train, params)
        grads = back_propagate(X_train, Y_train, params, cache)
        
        # Update parameters
        V_dW1 = (beta * V_dW1 + (1. - beta) * grads["dW1"])
        V_db1 = (beta * V_db1 + (1. - beta) * grads["db1"])
        V_dW2 = (beta * V_dW2 + (1. - beta) * grads["dW2"])
        V_db2 = (beta * V_db2 + (1. - beta) * grads["db2"])

        params["W1"] = params["W1"] - learning_rate * V_dW1
        params["b1"] = params["b1"] - learning_rate * V_db1
        params["W2"] = params["W2"] - learning_rate * V_dW2
        params["b2"] = params["b2"] - learning_rate * V_db2
    
    # Train accuracy
    cache = feed_forward(X_train, params)
    trainpredictions = np.argmax(cache["A2"], axis=0)
    trainlabels = np.argmax(Y_train, axis=0)
    train_acc = accuracy_metric(trainlabels, trainpredictions)
    train_accuracy.append(train_acc)
    
    # Train loss
    train_cost = compute_loss(Y_train, cache["A2"])
    train_history.append(train_cost)
    
    # Test accuracy
    cache = feed_forward(X_test, params)
    testpredictions = np.argmax(cache["A2"], axis=0)
    testlabels = np.argmax(Y_test, axis=0)
    test_acc = accuracy_metric(testlabels, testpredictions)
    test_accuracy.append(test_acc)
    
    # Test loss
    test_cost = compute_loss(Y_test, cache["A2"])
    test_history.append(test_cost)
    
    
    print("Epoch {}: train loss = {:.2f}, test loss = {:.2f}, train acc = {:.2f}, test acc = {:.2f}".format(i+1 ,train_cost, test_cost, train_acc, test_acc))

print("Done.")
# Out:
# Epoch 1: train loss = 2.61, test loss = 2.53, train acc = 32.50, test acc = 36.67
# Epoch 2: train loss = 1.13, test loss = 1.17, train acc = 35.00, test acc = 26.67
# Epoch 3: train loss = 1.12, test loss = 1.11, train acc = 32.50, test acc = 36.67
# Epoch 4: train loss = 1.10, test loss = 1.12, train acc = 42.08, test acc = 35.00
# Epoch 5: train loss = 1.08, test loss = 1.08, train acc = 34.58, test acc = 38.33
# Epoch 6: train loss = 1.07, test loss = 1.09, train acc = 39.58, test acc = 31.67
# Epoch 7: train loss = 1.06, test loss = 1.08, train acc = 43.33, test acc = 43.33
# Epoch 8: train loss = 1.04, test loss = 1.08, train acc = 54.58, test acc = 41.67
# Epoch 9: train loss = 1.03, test loss = 1.08, train acc = 55.83, test acc = 41.67
# Epoch 10: train loss = 1.01, test loss = 1.08, train acc = 58.33, test acc = 45.00
# Epoch 11: train loss = 1.04, test loss = 1.08, train acc = 40.83, test acc = 41.67
# Epoch 12: train loss = 1.01, test loss = 1.05, train acc = 52.08, test acc = 51.67
# Epoch 13: train loss = 1.01, test loss = 1.08, train acc = 54.58, test acc = 30.00
# Epoch 14: train loss = 0.98, test loss = 1.06, train acc = 55.00, test acc = 46.67
# Epoch 15: train loss = 0.97, test loss = 1.09, train acc = 55.83, test acc = 41.67
# Epoch 16: train loss = 0.98, test loss = 1.06, train acc = 52.50, test acc = 48.33
# Epoch 17: train loss = 0.99, test loss = 1.08, train acc = 47.50, test acc = 50.00
# Epoch 18: train loss = 0.98, test loss = 1.05, train acc = 50.83, test acc = 43.33
# Epoch 19: train loss = 0.96, test loss = 1.12, train acc = 48.33, test acc = 35.00
# Epoch 20: train loss = 0.98, test loss = 1.10, train acc = 48.75, test acc = 38.33
# Epoch 21: train loss = 0.96, test loss = 1.10, train acc = 52.08, test acc = 31.67
# Epoch 22: train loss = 0.96, test loss = 1.11, train acc = 58.33, test acc = 41.67
# Epoch 23: train loss = 0.90, test loss = 1.08, train acc = 61.25, test acc = 45.00
# Epoch 24: train loss = 1.07, test loss = 1.08, train acc = 49.58, test acc = 45.00
# Epoch 25: train loss = 0.96, test loss = 1.14, train acc = 48.33, test acc = 31.67
# Epoch 26: train loss = 0.95, test loss = 1.14, train acc = 62.08, test acc = 35.00
# Epoch 27: train loss = 0.91, test loss = 1.17, train acc = 55.83, test acc = 30.00
# Epoch 28: train loss = 0.89, test loss = 1.08, train acc = 59.58, test acc = 43.33
# Epoch 29: train loss = 0.86, test loss = 1.10, train acc = 60.42, test acc = 41.67
# Epoch 30: train loss = 0.83, test loss = 1.10, train acc = 62.50, test acc = 43.33
# Epoch 31: train loss = 0.86, test loss = 1.19, train acc = 60.42, test acc = 36.67
# Epoch 32: train loss = 0.84, test loss = 1.12, train acc = 62.08, test acc = 38.33
# Epoch 33: train loss = 0.92, test loss = 1.14, train acc = 54.17, test acc = 40.00
# Epoch 34: train loss = 0.97, test loss = 1.05, train acc = 53.75, test acc = 46.67
# Epoch 35: train loss = 0.89, test loss = 1.11, train acc = 59.17, test acc = 38.33
# Epoch 36: train loss = 1.13, test loss = 1.18, train acc = 34.17, test acc = 38.33
# Epoch 37: train loss = 0.96, test loss = 1.07, train acc = 50.83, test acc = 26.67
# Epoch 38: train loss = 0.94, test loss = 1.12, train acc = 55.42, test acc = 40.00
# Epoch 39: train loss = 1.10, test loss = 1.21, train acc = 37.08, test acc = 38.33
# Epoch 40: train loss = 0.96, test loss = 1.08, train acc = 64.17, test acc = 38.33
# Epoch 41: train loss = 1.11, test loss = 1.11, train acc = 36.67, test acc = 40.00
# Epoch 42: train loss = 1.05, test loss = 1.12, train acc = 40.42, test acc = 31.67
# Epoch 43: train loss = 0.99, test loss = 1.06, train acc = 56.67, test acc = 43.33
# Epoch 44: train loss = 0.93, test loss = 1.18, train acc = 59.58, test acc = 38.33
# Epoch 45: train loss = 0.85, test loss = 1.11, train acc = 63.33, test acc = 43.33
# Epoch 46: train loss = 0.85, test loss = 1.14, train acc = 62.50, test acc = 46.67
# Epoch 47: train loss = 1.04, test loss = 1.18, train acc = 44.58, test acc = 45.00
# Epoch 48: train loss = 0.93, test loss = 1.11, train acc = 60.42, test acc = 43.33
# Epoch 49: train loss = 0.90, test loss = 1.14, train acc = 59.17, test acc = 31.67
# Epoch 50: train loss = 0.89, test loss = 1.17, train acc = 68.75, test acc = 25.00
# Epoch 51: train loss = 0.85, test loss = 1.18, train acc = 64.17, test acc = 38.33
# Epoch 52: train loss = 0.90, test loss = 1.24, train acc = 52.92, test acc = 35.00
# Epoch 53: train loss = 0.88, test loss = 1.14, train acc = 62.08, test acc = 40.00
# Epoch 54: train loss = 0.94, test loss = 1.21, train acc = 55.00, test acc = 40.00
# Epoch 55: train loss = 0.94, test loss = 1.11, train acc = 55.00, test acc = 43.33
# Epoch 56: train loss = 0.92, test loss = 1.22, train acc = 52.08, test acc = 33.33
# Epoch 57: train loss = 0.84, test loss = 1.10, train acc = 62.50, test acc = 43.33
# Epoch 58: train loss = 0.83, test loss = 1.13, train acc = 70.00, test acc = 33.33
# Epoch 59: train loss = 0.81, test loss = 1.13, train acc = 66.67, test acc = 43.33
# Epoch 60: train loss = 0.80, test loss = 1.10, train acc = 65.00, test acc = 45.00
# Epoch 61: train loss = 0.79, test loss = 1.16, train acc = 72.50, test acc = 43.33
# Epoch 62: train loss = 1.24, test loss = 1.41, train acc = 37.08, test acc = 38.33
# Epoch 63: train loss = 1.11, test loss = 1.14, train acc = 40.00, test acc = 38.33
# Epoch 64: train loss = 1.06, test loss = 1.14, train acc = 38.33, test acc = 23.33
# Epoch 65: train loss = 1.03, test loss = 1.13, train acc = 39.17, test acc = 26.67
# Epoch 66: train loss = 0.90, test loss = 1.11, train acc = 70.42, test acc = 40.00
# Epoch 67: train loss = 1.15, test loss = 1.23, train acc = 38.33, test acc = 38.33
# Epoch 68: train loss = 1.07, test loss = 1.10, train acc = 37.50, test acc = 36.67
# Epoch 69: train loss = 1.08, test loss = 1.16, train acc = 35.00, test acc = 26.67
# Epoch 70: train loss = 1.03, test loss = 1.08, train acc = 38.75, test acc = 26.67
# Epoch 71: train loss = 0.92, test loss = 1.11, train acc = 50.83, test acc = 35.00
# Epoch 72: train loss = 0.86, test loss = 1.15, train acc = 66.67, test acc = 35.00
# Epoch 73: train loss = 0.91, test loss = 1.17, train acc = 52.08, test acc = 28.33
# Epoch 74: train loss = 1.13, test loss = 1.26, train acc = 40.42, test acc = 28.33
# Epoch 75: train loss = 1.05, test loss = 1.12, train acc = 38.75, test acc = 33.33
# Epoch 76: train loss = 1.01, test loss = 1.10, train acc = 42.08, test acc = 31.67
# Epoch 77: train loss = 1.03, test loss = 1.09, train acc = 48.33, test acc = 41.67
# Epoch 78: train loss = 1.00, test loss = 1.09, train acc = 49.17, test acc = 41.67
# Epoch 79: train loss = 1.01, test loss = 1.12, train acc = 48.75, test acc = 33.33
# Epoch 80: train loss = 1.02, test loss = 1.19, train acc = 39.58, test acc = 31.67
# Epoch 81: train loss = 0.99, test loss = 1.09, train acc = 54.17, test acc = 33.33
# Epoch 82: train loss = 1.09, test loss = 1.15, train acc = 40.42, test acc = 38.33
# Epoch 83: train loss = 1.00, test loss = 1.14, train acc = 51.67, test acc = 36.67
# Epoch 84: train loss = 0.97, test loss = 1.18, train acc = 50.42, test acc = 33.33
# Epoch 85: train loss = 0.89, test loss = 1.18, train acc = 57.08, test acc = 38.33
# Epoch 86: train loss = 0.92, test loss = 1.13, train acc = 56.67, test acc = 43.33
# Epoch 87: train loss = 0.81, test loss = 1.12, train acc = 68.33, test acc = 45.00
# Epoch 88: train loss = 0.82, test loss = 1.11, train acc = 66.67, test acc = 45.00
# Epoch 89: train loss = 0.86, test loss = 1.07, train acc = 61.25, test acc = 46.67
# Epoch 90: train loss = 0.79, test loss = 1.22, train acc = 71.67, test acc = 33.33
# Epoch 91: train loss = 0.76, test loss = 1.15, train acc = 73.75, test acc = 40.00
# Epoch 92: train loss = 0.82, test loss = 1.27, train acc = 61.25, test acc = 41.67
# Epoch 93: train loss = 0.84, test loss = 1.12, train acc = 60.42, test acc = 41.67
# Epoch 94: train loss = 1.07, test loss = 1.21, train acc = 43.75, test acc = 31.67
# Epoch 95: train loss = 0.82, test loss = 1.12, train acc = 66.67, test acc = 43.33
# Epoch 96: train loss = 0.99, test loss = 1.27, train acc = 51.25, test acc = 40.00
# Epoch 97: train loss = 1.04, test loss = 1.10, train acc = 37.92, test acc = 28.33
# Epoch 98: train loss = 1.05, test loss = 1.08, train acc = 52.92, test acc = 35.00
# Epoch 99: train loss = 0.99, test loss = 1.07, train acc = 65.00, test acc = 48.33
# Epoch 100: train loss = 1.01, test loss = 1.08, train acc = 53.75, test acc = 38.33
# Epoch 101: train loss = 0.99, test loss = 1.08, train acc = 60.83, test acc = 35.00
# Epoch 102: train loss = 0.97, test loss = 1.06, train acc = 66.25, test acc = 41.67
# Epoch 103: train loss = 0.95, test loss = 1.11, train acc = 59.17, test acc = 30.00
# Epoch 104: train loss = 0.98, test loss = 1.11, train acc = 50.42, test acc = 31.67
# Epoch 105: train loss = 0.94, test loss = 1.13, train acc = 52.50, test acc = 35.00
# Epoch 106: train loss = 1.01, test loss = 1.09, train acc = 50.42, test acc = 35.00
# Epoch 107: train loss = 0.97, test loss = 1.06, train acc = 62.92, test acc = 43.33
# Epoch 108: train loss = 1.08, test loss = 1.16, train acc = 37.92, test acc = 30.00
# Epoch 109: train loss = 0.96, test loss = 1.11, train acc = 52.50, test acc = 38.33
# Epoch 110: train loss = 0.98, test loss = 1.09, train acc = 50.83, test acc = 41.67
# Epoch 111: train loss = 1.10, test loss = 1.22, train acc = 36.25, test acc = 26.67
# Epoch 112: train loss = 0.99, test loss = 1.06, train acc = 54.17, test acc = 43.33
# Epoch 113: train loss = 0.95, test loss = 1.10, train acc = 64.17, test acc = 28.33
# Epoch 114: train loss = 0.93, test loss = 1.05, train acc = 59.17, test acc = 46.67
# Epoch 115: train loss = 0.90, test loss = 1.09, train acc = 68.33, test acc = 38.33
# Epoch 116: train loss = 0.94, test loss = 1.10, train acc = 57.50, test acc = 41.67
# Epoch 117: train loss = 0.94, test loss = 1.12, train acc = 55.00, test acc = 30.00
# Epoch 118: train loss = 1.15, test loss = 1.18, train acc = 37.08, test acc = 36.67
# Epoch 119: train loss = 1.06, test loss = 1.09, train acc = 38.33, test acc = 31.67
# Epoch 120: train loss = 1.06, test loss = 1.11, train acc = 44.58, test acc = 26.67
# Epoch 121: train loss = 1.01, test loss = 1.07, train acc = 57.92, test acc = 35.00
# Epoch 122: train loss = 1.04, test loss = 1.13, train acc = 39.58, test acc = 30.00
# Epoch 123: train loss = 1.01, test loss = 1.08, train acc = 53.75, test acc = 36.67
# Epoch 124: train loss = 0.99, test loss = 1.13, train acc = 48.75, test acc = 30.00
# Epoch 125: train loss = 1.02, test loss = 1.14, train acc = 40.00, test acc = 28.33
# Epoch 126: train loss = 0.98, test loss = 1.07, train acc = 62.08, test acc = 36.67
# Epoch 127: train loss = 0.96, test loss = 1.08, train acc = 58.33, test acc = 36.67
# Epoch 128: train loss = 0.96, test loss = 1.09, train acc = 57.50, test acc = 43.33
# Epoch 129: train loss = 0.94, test loss = 1.08, train acc = 60.00, test acc = 45.00
# Epoch 130: train loss = 0.94, test loss = 1.07, train acc = 57.08, test acc = 40.00
# Epoch 131: train loss = 1.13, test loss = 1.14, train acc = 34.58, test acc = 36.67
# Epoch 132: train loss = 1.13, test loss = 1.27, train acc = 35.83, test acc = 26.67
# Epoch 133: train loss = 1.07, test loss = 1.08, train acc = 46.25, test acc = 43.33
# Epoch 134: train loss = 1.05, test loss = 1.11, train acc = 45.42, test acc = 30.00
# Epoch 135: train loss = 1.05, test loss = 1.14, train acc = 37.50, test acc = 28.33
# Epoch 136: train loss = 1.05, test loss = 1.08, train acc = 48.33, test acc = 40.00
# Epoch 137: train loss = 1.10, test loss = 1.08, train acc = 35.83, test acc = 40.00
# Epoch 138: train loss = 1.04, test loss = 1.13, train acc = 37.08, test acc = 28.33
# Epoch 139: train loss = 1.08, test loss = 1.08, train acc = 44.58, test acc = 43.33
# Epoch 140: train loss = 1.11, test loss = 1.20, train acc = 37.50, test acc = 28.33
# Epoch 141: train loss = 1.10, test loss = 1.09, train acc = 36.25, test acc = 40.00
# Epoch 142: train loss = 1.03, test loss = 1.16, train acc = 37.50, test acc = 28.33
# Epoch 143: train loss = 1.00, test loss = 1.11, train acc = 42.92, test acc = 30.00
# Epoch 144: train loss = 0.97, test loss = 1.06, train acc = 58.33, test acc = 36.67
# Epoch 145: train loss = 0.93, test loss = 1.07, train acc = 63.33, test acc = 41.67
# Epoch 146: train loss = 0.95, test loss = 1.12, train acc = 53.33, test acc = 31.67
# Epoch 147: train loss = 1.03, test loss = 1.19, train acc = 38.75, test acc = 28.33
# Epoch 148: train loss = 0.95, test loss = 1.09, train acc = 57.92, test acc = 43.33
# Epoch 149: train loss = 0.90, test loss = 1.07, train acc = 66.25, test acc = 45.00
# Epoch 150: train loss = 0.98, test loss = 1.09, train acc = 46.25, test acc = 40.00
# Epoch 151: train loss = 0.91, test loss = 1.14, train acc = 56.67, test acc = 35.00
# Epoch 152: train loss = 0.94, test loss = 1.13, train acc = 59.58, test acc = 38.33
# Epoch 153: train loss = 0.97, test loss = 1.10, train acc = 52.08, test acc = 33.33
# Epoch 154: train loss = 0.95, test loss = 1.10, train acc = 53.33, test acc = 33.33
# Epoch 155: train loss = 1.07, test loss = 1.17, train acc = 45.00, test acc = 26.67
# Epoch 156: train loss = 1.00, test loss = 1.08, train acc = 55.00, test acc = 31.67
# Epoch 157: train loss = 1.03, test loss = 1.09, train acc = 50.83, test acc = 33.33
# Epoch 158: train loss = 0.99, test loss = 1.16, train acc = 43.75, test acc = 30.00
# Epoch 159: train loss = 0.97, test loss = 1.08, train acc = 52.92, test acc = 33.33
# Epoch 160: train loss = 1.01, test loss = 1.13, train acc = 46.67, test acc = 31.67
# Epoch 161: train loss = 1.01, test loss = 1.12, train acc = 53.75, test acc = 26.67
# Epoch 162: train loss = 0.99, test loss = 1.10, train acc = 50.42, test acc = 30.00
# Epoch 163: train loss = 1.04, test loss = 1.19, train acc = 41.25, test acc = 28.33
# Epoch 164: train loss = 0.96, test loss = 1.10, train acc = 48.33, test acc = 31.67
# Epoch 165: train loss = 0.87, test loss = 1.11, train acc = 60.83, test acc = 41.67
# Epoch 166: train loss = 0.94, test loss = 1.08, train acc = 47.08, test acc = 48.33
# Epoch 167: train loss = 0.88, test loss = 1.12, train acc = 57.92, test acc = 38.33
# Epoch 168: train loss = 0.81, test loss = 1.11, train acc = 68.33, test acc = 41.67
# Epoch 169: train loss = 0.88, test loss = 1.11, train acc = 49.58, test acc = 45.00
# Epoch 170: train loss = 0.86, test loss = 1.09, train acc = 67.08, test acc = 41.67
# Epoch 171: train loss = 0.91, test loss = 1.08, train acc = 49.17, test acc = 36.67
# Epoch 172: train loss = 1.06, test loss = 1.31, train acc = 48.75, test acc = 40.00
# Epoch 173: train loss = 1.02, test loss = 1.13, train acc = 44.58, test acc = 40.00
# Epoch 174: train loss = 1.03, test loss = 1.09, train acc = 42.08, test acc = 30.00
# Epoch 175: train loss = 0.97, test loss = 1.08, train acc = 57.50, test acc = 46.67
# Epoch 176: train loss = 0.99, test loss = 1.17, train acc = 43.75, test acc = 33.33
# Epoch 177: train loss = 0.98, test loss = 1.09, train acc = 55.42, test acc = 43.33
# Epoch 178: train loss = 0.97, test loss = 1.14, train acc = 54.17, test acc = 40.00
# Epoch 179: train loss = 1.10, test loss = 1.11, train acc = 34.58, test acc = 41.67
# Epoch 180: train loss = 1.07, test loss = 1.11, train acc = 40.00, test acc = 28.33
# Epoch 181: train loss = 1.04, test loss = 1.08, train acc = 47.08, test acc = 40.00
# Epoch 182: train loss = 1.02, test loss = 1.10, train acc = 45.42, test acc = 28.33
# Epoch 183: train loss = 1.06, test loss = 1.07, train acc = 35.83, test acc = 38.33
# Epoch 184: train loss = 0.95, test loss = 1.07, train acc = 59.58, test acc = 30.00
# Epoch 185: train loss = 0.93, test loss = 1.18, train acc = 52.08, test acc = 31.67
# Epoch 186: train loss = 0.95, test loss = 1.07, train acc = 58.75, test acc = 46.67
# Epoch 187: train loss = 1.02, test loss = 1.07, train acc = 44.58, test acc = 43.33
# Epoch 188: train loss = 0.97, test loss = 1.09, train acc = 48.75, test acc = 40.00
# Epoch 189: train loss = 0.96, test loss = 1.09, train acc = 50.00, test acc = 41.67
# Epoch 190: train loss = 0.93, test loss = 1.11, train acc = 53.33, test acc = 36.67
# Epoch 191: train loss = 1.00, test loss = 1.17, train acc = 46.67, test acc = 28.33
# Epoch 192: train loss = 0.93, test loss = 1.08, train acc = 53.33, test acc = 41.67
# Epoch 193: train loss = 1.02, test loss = 1.09, train acc = 46.25, test acc = 40.00
# Epoch 194: train loss = 0.94, test loss = 1.15, train acc = 54.58, test acc = 35.00
# Epoch 195: train loss = 0.89, test loss = 1.10, train acc = 55.00, test acc = 38.33
# Epoch 196: train loss = 0.89, test loss = 1.09, train acc = 55.00, test acc = 41.67
# Epoch 197: train loss = 0.98, test loss = 1.12, train acc = 50.83, test acc = 40.00
# Epoch 198: train loss = 0.92, test loss = 1.14, train acc = 55.42, test acc = 43.33
# Epoch 199: train loss = 0.95, test loss = 1.18, train acc = 57.92, test acc = 38.33
# Epoch 200: train loss = 0.99, test loss = 1.07, train acc = 42.08, test acc = 40.00
# Epoch 201: train loss = 1.00, test loss = 1.21, train acc = 41.67, test acc = 28.33
# Epoch 202: train loss = 0.91, test loss = 1.17, train acc = 53.33, test acc = 33.33
# Epoch 203: train loss = 0.97, test loss = 1.17, train acc = 49.58, test acc = 40.00
# Epoch 204: train loss = 0.94, test loss = 1.19, train acc = 53.33, test acc = 33.33
# Epoch 205: train loss = 0.88, test loss = 1.11, train acc = 60.83, test acc = 43.33
# Epoch 206: train loss = 0.86, test loss = 1.10, train acc = 55.42, test acc = 40.00
# Epoch 207: train loss = 0.85, test loss = 1.10, train acc = 67.08, test acc = 45.00
# Epoch 208: train loss = 0.89, test loss = 1.17, train acc = 64.17, test acc = 36.67
# Epoch 209: train loss = 0.89, test loss = 1.10, train acc = 67.92, test acc = 46.67
# Epoch 210: train loss = 0.91, test loss = 1.15, train acc = 56.67, test acc = 40.00
# Epoch 211: train loss = 1.14, test loss = 1.29, train acc = 39.58, test acc = 33.33
# Epoch 212: train loss = 1.05, test loss = 1.14, train acc = 43.33, test acc = 31.67
# Epoch 213: train loss = 1.03, test loss = 1.14, train acc = 41.25, test acc = 28.33
# Epoch 214: train loss = 0.96, test loss = 1.13, train acc = 52.92, test acc = 30.00
# Epoch 215: train loss = 0.95, test loss = 1.12, train acc = 49.58, test acc = 41.67
# Epoch 216: train loss = 0.95, test loss = 1.13, train acc = 60.83, test acc = 36.67
# Epoch 217: train loss = 0.95, test loss = 1.18, train acc = 57.50, test acc = 33.33
# Epoch 218: train loss = 0.90, test loss = 1.17, train acc = 60.42, test acc = 28.33
# Epoch 219: train loss = 0.91, test loss = 1.12, train acc = 57.08, test acc = 28.33
# Epoch 220: train loss = 0.84, test loss = 1.17, train acc = 58.75, test acc = 33.33
# Epoch 221: train loss = 1.04, test loss = 1.14, train acc = 39.58, test acc = 36.67
# Epoch 222: train loss = 0.99, test loss = 1.14, train acc = 45.42, test acc = 36.67
# Epoch 223: train loss = 1.09, test loss = 1.27, train acc = 42.50, test acc = 31.67
# Epoch 224: train loss = 1.00, test loss = 1.17, train acc = 41.67, test acc = 36.67
# Epoch 225: train loss = 1.00, test loss = 1.11, train acc = 49.17, test acc = 38.33
# Epoch 226: train loss = 0.93, test loss = 1.19, train acc = 42.08, test acc = 30.00
# Epoch 227: train loss = 1.00, test loss = 1.13, train acc = 46.67, test acc = 33.33
# Epoch 228: train loss = 0.98, test loss = 1.13, train acc = 51.25, test acc = 36.67
# Epoch 229: train loss = 0.93, test loss = 1.16, train acc = 65.83, test acc = 43.33
# Epoch 230: train loss = 1.05, test loss = 1.16, train acc = 40.00, test acc = 36.67
# Epoch 231: train loss = 1.00, test loss = 1.17, train acc = 41.25, test acc = 26.67
# Epoch 232: train loss = 0.98, test loss = 1.19, train acc = 54.17, test acc = 35.00
# Epoch 233: train loss = 0.94, test loss = 1.21, train acc = 54.17, test acc = 35.00
# Epoch 234: train loss = 0.87, test loss = 1.18, train acc = 56.67, test acc = 41.67
# Epoch 235: train loss = 0.86, test loss = 1.13, train acc = 61.67, test acc = 43.33
# Epoch 236: train loss = 0.92, test loss = 1.11, train acc = 47.92, test acc = 40.00
# Epoch 237: train loss = 1.10, test loss = 1.40, train acc = 42.92, test acc = 30.00
# Epoch 238: train loss = 0.85, test loss = 1.25, train acc = 61.25, test acc = 31.67
# Epoch 239: train loss = 0.79, test loss = 1.16, train acc = 70.00, test acc = 41.67
# Epoch 240: train loss = 0.84, test loss = 1.13, train acc = 57.50, test acc = 40.00
# Epoch 241: train loss = 0.83, test loss = 1.14, train acc = 64.17, test acc = 41.67
# Epoch 242: train loss = 0.80, test loss = 1.17, train acc = 59.17, test acc = 38.33
# Epoch 243: train loss = 0.85, test loss = 1.18, train acc = 62.50, test acc = 43.33
# Epoch 244: train loss = 0.95, test loss = 1.35, train acc = 58.75, test acc = 33.33
# Epoch 245: train loss = 0.83, test loss = 1.13, train acc = 62.92, test acc = 43.33
# Epoch 246: train loss = 0.93, test loss = 1.21, train acc = 62.50, test acc = 36.67
# Epoch 247: train loss = 0.89, test loss = 1.31, train acc = 57.92, test acc = 33.33
# Epoch 248: train loss = 0.80, test loss = 1.15, train acc = 65.00, test acc = 38.33
# Epoch 249: train loss = 0.91, test loss = 1.21, train acc = 59.58, test acc = 40.00
# Epoch 250: train loss = 0.88, test loss = 1.24, train acc = 60.83, test acc = 36.67
# Epoch 251: train loss = 0.97, test loss = 1.21, train acc = 56.25, test acc = 35.00
# Epoch 252: train loss = 1.10, test loss = 1.16, train acc = 37.50, test acc = 36.67
# Epoch 253: train loss = 1.01, test loss = 1.15, train acc = 42.08, test acc = 30.00
# Epoch 254: train loss = 0.93, test loss = 1.08, train acc = 51.67, test acc = 31.67
# Epoch 255: train loss = 1.14, test loss = 1.14, train acc = 36.67, test acc = 38.33
# Epoch 256: train loss = 1.00, test loss = 1.17, train acc = 40.83, test acc = 28.33
# Epoch 257: train loss = 1.00, test loss = 1.08, train acc = 50.42, test acc = 38.33
# Epoch 258: train loss = 0.95, test loss = 1.13, train acc = 54.17, test acc = 31.67
# Epoch 259: train loss = 0.93, test loss = 1.12, train acc = 58.33, test acc = 31.67
# Epoch 260: train loss = 1.15, test loss = 1.14, train acc = 37.08, test acc = 45.00
# Epoch 261: train loss = 1.02, test loss = 1.19, train acc = 42.92, test acc = 31.67
# Epoch 262: train loss = 1.00, test loss = 1.09, train acc = 50.00, test acc = 41.67
# Epoch 263: train loss = 1.00, test loss = 1.09, train acc = 46.25, test acc = 40.00
# Epoch 264: train loss = 1.01, test loss = 1.08, train acc = 50.83, test acc = 46.67
# Epoch 265: train loss = 0.97, test loss = 1.08, train acc = 57.08, test acc = 40.00
# Epoch 266: train loss = 1.10, test loss = 1.10, train acc = 35.83, test acc = 38.33
# Epoch 267: train loss = 1.08, test loss = 1.18, train acc = 41.25, test acc = 30.00
# Epoch 268: train loss = 1.06, test loss = 1.08, train acc = 36.67, test acc = 38.33
# Epoch 269: train loss = 1.03, test loss = 1.10, train acc = 41.25, test acc = 31.67
# Epoch 270: train loss = 1.03, test loss = 1.07, train acc = 44.17, test acc = 40.00
# Epoch 271: train loss = 1.06, test loss = 1.12, train acc = 41.25, test acc = 31.67
# Epoch 272: train loss = 1.04, test loss = 1.08, train acc = 48.33, test acc = 28.33
# Epoch 273: train loss = 1.02, test loss = 1.08, train acc = 47.08, test acc = 40.00
# Epoch 274: train loss = 1.01, test loss = 1.07, train acc = 54.17, test acc = 38.33
# Epoch 275: train loss = 0.98, test loss = 1.07, train acc = 55.42, test acc = 41.67
# Epoch 276: train loss = 0.99, test loss = 1.08, train acc = 55.00, test acc = 35.00
# Epoch 277: train loss = 1.04, test loss = 1.10, train acc = 42.50, test acc = 31.67
# Epoch 278: train loss = 1.03, test loss = 1.10, train acc = 35.00, test acc = 38.33
# Epoch 279: train loss = 0.90, test loss = 1.11, train acc = 63.33, test acc = 43.33
# Epoch 280: train loss = 1.13, test loss = 1.12, train acc = 36.67, test acc = 41.67
# Epoch 281: train loss = 1.11, test loss = 1.22, train acc = 40.00, test acc = 28.33
# Epoch 282: train loss = 1.09, test loss = 1.12, train acc = 37.50, test acc = 36.67
# Epoch 283: train loss = 1.03, test loss = 1.16, train acc = 40.42, test acc = 30.00
# Epoch 284: train loss = 1.01, test loss = 1.09, train acc = 47.08, test acc = 38.33
# Epoch 285: train loss = 0.98, test loss = 1.09, train acc = 55.42, test acc = 35.00
# Epoch 286: train loss = 1.00, test loss = 1.14, train acc = 50.00, test acc = 26.67
# Epoch 287: train loss = 1.00, test loss = 1.09, train acc = 50.83, test acc = 36.67
# Epoch 288: train loss = 1.03, test loss = 1.12, train acc = 42.08, test acc = 33.33
# Epoch 289: train loss = 0.99, test loss = 1.11, train acc = 47.92, test acc = 33.33
# Epoch 290: train loss = 0.97, test loss = 1.08, train acc = 62.08, test acc = 43.33
# Epoch 291: train loss = 1.04, test loss = 1.15, train acc = 42.92, test acc = 30.00
# Epoch 292: train loss = 0.98, test loss = 1.09, train acc = 53.33, test acc = 41.67
# Epoch 293: train loss = 0.96, test loss = 1.08, train acc = 57.08, test acc = 38.33
# Epoch 294: train loss = 0.96, test loss = 1.13, train acc = 56.67, test acc = 33.33
# Epoch 295: train loss = 1.09, test loss = 1.18, train acc = 40.83, test acc = 30.00
# Epoch 296: train loss = 1.10, test loss = 1.15, train acc = 38.33, test acc = 41.67
# Epoch 297: train loss = 0.95, test loss = 1.08, train acc = 59.17, test acc = 41.67
# Epoch 298: train loss = 0.99, test loss = 1.09, train acc = 51.67, test acc = 38.33
# Epoch 299: train loss = 0.95, test loss = 1.12, train acc = 56.25, test acc = 33.33
# Epoch 300: train loss = 1.01, test loss = 1.19, train acc = 49.17, test acc = 30.00
# Done.

# %% [markdown]
# ## Model Evaluation

# %% [markdown]
# Visualize loss for every epoch

# %%
plt.title('Train and Test loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.plot(epoch, train_history, 'g', label = 'Train Loss')
plt.plot(epoch, test_history, 'b', label = 'Test Loss')
plt.legend()
plt.show()

# %% [markdown]
# Average loss

# %%
import statistics

train_l = statistics.mean(train_history)
test_l = statistics.mean(test_history)
print('Average train loss = {:.2f}'.format(train_l))
print('Average test loss = {:.2f}'.format(test_l))
# Out:
# Average train loss = 0.98
# Average test loss = 1.13

# %% [markdown]
# Visualize accuracy for every epoch

# %%
plt.title('Train and Test Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.plot(epoch, train_accuracy, 'r', label = 'Train Accuracy')
plt.plot(epoch, test_accuracy, 'y', label = 'Test Accuracy')
plt.legend()
plt.show()

# %%
train_a = statistics.mean(train_accuracy)
test_a = statistics.mean(test_accuracy)
print('Average train accuracy = {:.2f}'.format(train_a))
print('Average test accuracy = {:.2f}'.format(test_a))
# Out:
# Average train accuracy = 51.29
# Average test accuracy = 36.87

# %% [markdown]
# # Convolutional Neural Network

# %% [markdown]
# Import required library

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Conv2D, Flatten, Dropout, MaxPooling2D
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# ## Data Preparation

# %%
# Set the path of the input folder 
data_path = "/Users/Haekal/Documents/ML/input/flowers/flowers/"

# List out the directories inside the main input folder
folders = os.listdir(data_path)
folders.remove('.DS_Store')
folders.remove('dandelion')
folders.remove('sunflower')

print(folders)
# Out:
# ['daisy', 'rose', 'tulip']

# %%
# Resize image
size1 = 320
size2 = 240

# lists to store data
data = []
label = []

for folder in folders:
    for file in os.listdir(os.path.join(data_path,folder)):
        if file.endswith("jpg"):
            img = cv2.imread(os.path.join(data_path,folder,file))
            img = cv2.resize(img, (size1,size2))
            data.append(img)
            label.append(folder)
        else:
            continue

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# Split the data for training and testing

# %%
# Transforming into numpy array
data = np.array(data)
label = np.array(label)

# Split dataset into train and test sets
train_data, test_data, train_label, test_label = train_test_split(data, label, test_size=0.2, random_state=42)

# Get the categories/classes
label_categories = np.unique(label)
test_label_names = test_label

# %% [markdown]
# One hot encoding for target/label variable

# %%
# Transforming object categories into numerical
encoder = LabelEncoder()

train_label = encoder.fit_transform(train_label).astype(int)
test_label = encoder.fit_transform(test_label).astype(int)

# %% [markdown]
# Normalize image data

# %%
datagen_train = ImageDataGenerator(rescale=1./255)
datagen_valid = ImageDataGenerator(rescale=1./255)

datagen_train.fit(train_data)
datagen_valid.fit(test_data)

# %%
test_data.shape
# Out:
# (60, 240, 320, 3)

# %%
train_data.shape
# Out:
# (240, 240, 320, 3)

# %% [markdown]
# ## Model Training

# %% [markdown]
# Build model

# %%
# CNN architecture
classifier = Sequential([
    Conv2D(32, (5,5), padding='same', activation='relu', input_shape=(size2, size1,3)),
    MaxPooling2D(2,2),
    Flatten(),
    Dense(32, activation='relu'),
    Dense(3, activation='softmax')
])

# Visualize model summary
classifier.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 240, 320, 32)      2432
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 120, 160, 32)      0
# _________________________________________________________________
# flatten (Flatten)            (None, 614400)            0
# _________________________________________________________________
# dense (Dense)                (None, 32)                19660832
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 99
# =================================================================
# Total params: 19,663,363
# Trainable params: 19,663,363
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Compile model

# %%
classifier.compile(optimizer='Nadam', loss='sparse_categorical_crossentropy', metrics=["accuracy"])

# %% [markdown]
# Train and validate model

# %%
history = classifier.fit(datagen_train.flow(train_data, train_label, batch_size = 128),
                         validation_data = datagen_valid.flow(test_data, test_label, batch_size = 128), 
                         epochs=300)
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 2 steps, validate for 1 steps
# Epoch 1/300
# 2/2 [==============================] - 12s 6s/step - loss: 28.7655 - accuracy: 0.3042 - val_loss: 9.3779 - val_accuracy: 0.2667
# Epoch 2/300
# 2/2 [==============================] - 10s 5s/step - loss: 12.0539 - accuracy: 0.3417 - val_loss: 2.5022 - val_accuracy: 0.4167
# Epoch 3/300
# 2/2 [==============================] - 9s 4s/step - loss: 3.3815 - accuracy: 0.4042 - val_loss: 1.7734 - val_accuracy: 0.4500
# Epoch 4/300
# 2/2 [==============================] - 9s 4s/step - loss: 1.0990 - accuracy: 0.5958 - val_loss: 1.0663 - val_accuracy: 0.4833
# Epoch 5/300
# 2/2 [==============================] - 9s 4s/step - loss: 0.7181 - accuracy: 0.6875 - val_loss: 1.1209 - val_accuracy: 0.4667
# Epoch 6/300
# 2/2 [==============================] - 9s 4s/step - loss: 0.6384 - accuracy: 0.7125 - val_loss: 0.8903 - val_accuracy: 0.5667
# Epoch 7/300
# 2/2 [==============================] - 9s 5s/step - loss: 0.4848 - accuracy: 0.8208 - val_loss: 0.8466 - val_accuracy: 0.6667
# Epoch 8/300
# 2/2 [==============================] - 9s 4s/step - loss: 0.4142 - accuracy: 0.8792 - val_loss: 0.8746 - val_accuracy: 0.5833
# Epoch 9/300
# 2/2 [==============================] - 9s 4s/step - loss: 0.3696 - accuracy: 0.8917 - val_loss: 1.1616 - val_accuracy: 0.5667
# Epoch 10/300
# 2/2 [==============================] - 9s 4s/step - loss: 0.3661 - accuracy: 0.8833 - val_loss: 0.8764 - val_accuracy: 0.6333
# Epoch 11/300
# 2/2 [==============================] - 9s 4s/step - loss: 0.2511 - accuracy: 0.9458 - val_loss: 0.8935 - val_accuracy: 0.6000
# Epoch 12/300
# 2/2 [==============================] - 9s 4s/step - loss: 1.0671 - accuracy: 0.8083 - val_loss: 3.1036 - val_accuracy: 0.4000
# Epoch 13/300
# 2/2 [==============================] - 9s 4s/step - loss: 1.5588 - accuracy: 0.6167 - val_loss: 0.9198 - val_accuracy: 0.6667
# Epoch 14/300
# 2/2 [==============================] - 9s 4s/step - loss: 0.2985 - accuracy: 0.9708 - val_loss: 0.8980 - val_accuracy: 0.6500
# Epoch 15/300
# 2/2 [==============================] - 10s 5s/step - loss: 0.2555 - accuracy: 0.9750 - val_loss: 0.8881 - val_accuracy: 0.6167
# Epoch 16/300
# 2/2 [==============================] - 9s 4s/step - loss: 0.2267 - accuracy: 0.9833 - val_loss: 0.8929 - val_accuracy: 0.6167
# Epoch 17/300
# 2/2 [==============================] - 9s 4s/step - loss: 0.1976 - accuracy: 0.9833 - val_loss: 0.9119 - val_accuracy: 0.6167
# Epoch 18/300
# 2/2 [==============================] - 9s 4s/step - loss: 0.1715 - accuracy: 0.9792 - val_loss: 0.9319 - val_accuracy: 0.6000
# Epoch 19/300
# 2/2 [==============================] - 9s 4s/step - loss: 0.1480 - accuracy: 0.9792 - val_loss: 0.9438 - val_accuracy: 0.6000
# Epoch 20/300
# 2/2 [==============================] - 9s 4s/step - loss: 0.1272 - accuracy: 0.9792 - val_loss: 0.9533 - val_accuracy: 0.6000
# Epoch 21/300
# 2/2 [==============================] - 9s 5s/step - loss: 0.1081 - accuracy: 0.9792 - val_loss: 0.9728 - val_accuracy: 0.6167
# Epoch 22/300
# 2/2 [==============================] - 9s 4s/step - loss: 0.0917 - accuracy: 0.9833 - val_loss: 0.9839 - val_accuracy: 0.6333
# Epoch 23/300
# 2/2 [==============================] - 9s 4s/step - loss: 0.0774 - accuracy: 0.9833 - val_loss: 1.0032 - val_accuracy: 0.6333
# Epoch 24/300
# 2/2 [==============================] - 9s 4s/step - loss: 0.0664 - accuracy: 0.9833 - val_loss: 1.0017 - val_accuracy: 0.6167
# Epoch 25/300
# 2/2 [==============================] - 9s 4s/step - loss: 0.0568 - accuracy: 0.9875 - val_loss: 1.0042 - val_accuracy: 0.6167
# Epoch 26/300
# 2/2 [==============================] - 9s 4s/step - loss: 0.0489 - accuracy: 0.9958 - val_loss: 1.0112 - val_accuracy: 0.6167
# Epoch 27/300
# 2/2 [==============================] - 9s 4s/step - loss: 0.0417 - accuracy: 0.9958 - val_loss: 1.0210 - val_accuracy: 0.6167
# Epoch 28/300
# 2/2 [==============================] - 9s 4s/step - loss: 0.0358 - accuracy: 0.9958 - val_loss: 1.0068 - val_accuracy: 0.6167
# Epoch 29/300
# 2/2 [==============================] - 9s 4s/step - loss: 0.0309 - accuracy: 0.9958 - val_loss: 1.0296 - val_accuracy: 0.6000
# Epoch 30/300
# 2/2 [==============================] - 10s 5s/step - loss: 0.0267 - accuracy: 0.9958 - val_loss: 1.0413 - val_accuracy: 0.6000
# Epoch 31/300
# 2/2 [==============================] - 9s 4s/step - loss: 0.0230 - accuracy: 1.0000 - val_loss: 1.0719 - val_accuracy: 0.6000
# Epoch 32/300
# 2/2 [==============================] - 9s 4s/step - loss: 0.0206 - accuracy: 1.0000 - val_loss: 1.0801 - val_accuracy: 0.6167
# Epoch 33/300
# 2/2 [==============================] - 9s 5s/step - loss: 0.0180 - accuracy: 1.0000 - val_loss: 1.0808 - val_accuracy: 0.6000
# Epoch 34/300
# 2/2 [==============================] - 9s 4s/step - loss: 0.0164 - accuracy: 1.0000 - val_loss: 1.0805 - val_accuracy: 0.6000
# Epoch 35/300
# 2/2 [==============================] - 9s 5s/step - loss: 0.0146 - accuracy: 1.0000 - val_loss: 1.0963 - val_accuracy: 0.6000
# Epoch 36/300
# 2/2 [==============================] - 9s 4s/step - loss: 0.0129 - accuracy: 1.0000 - val_loss: 1.1103 - val_accuracy: 0.6167
# Epoch 37/300
# 2/2 [==============================] - 9s 4s/step - loss: 0.0118 - accuracy: 1.0000 - val_loss: 1.1153 - val_accuracy: 0.6167
# Epoch 38/300
# 2/2 [==============================] - 9s 4s/step - loss: 0.0106 - accuracy: 1.0000 - val_loss: 1.1186 - val_accuracy: 0.6167
# Epoch 39/300
# 2/2 [==============================] - 9s 4s/step - loss: 0.0096 - accuracy: 1.0000 - val_loss: 1.1276 - val_accuracy: 0.6167
# Epoch 40/300
# 2/2 [==============================] - 9s 4s/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 1.1226 - val_accuracy: 0.6333
# Epoch 41/300
# 2/2 [==============================] - 9s 4s/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 1.1216 - val_accuracy: 0.6333
# Epoch 42/300
# 2/2 [==============================] - 9s 5s/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 1.1280 - val_accuracy: 0.6333
# Epoch 43/300
# 2/2 [==============================] - 9s 5s/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 1.1362 - val_accuracy: 0.6167
# Epoch 44/300
# 2/2 [==============================] - 13s 7s/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 1.1396 - val_accuracy: 0.6167
# Epoch 45/300
# 2/2 [==============================] - 9s 4s/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 1.1386 - val_accuracy: 0.6167
# Epoch 46/300
# 2/2 [==============================] - 9s 4s/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 1.1448 - val_accuracy: 0.6167
# Epoch 47/300
# 2/2 [==============================] - 9s 4s/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 1.1478 - val_accuracy: 0.6167
# Epoch 48/300
# 2/2 [==============================] - 9s 4s/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 1.1491 - val_accuracy: 0.6167
# Epoch 49/300
# 2/2 [==============================] - 9s 4s/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 1.1524 - val_accuracy: 0.6167
# Epoch 50/300
# 2/2 [==============================] - 9s 4s/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 1.1564 - val_accuracy: 0.6167
# Epoch 51/300
# 2/2 [==============================] - 9s 4s/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 1.1598 - val_accuracy: 0.6167
# Epoch 52/300
# 2/2 [==============================] - 9s 5s/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 1.1626 - val_accuracy: 0.6167
# Epoch 53/300
# 2/2 [==============================] - 9s 4s/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 1.1643 - val_accuracy: 0.6167
# Epoch 54/300
# 2/2 [==============================] - 9s 5s/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 1.1694 - val_accuracy: 0.6167
# Epoch 55/300
# 2/2 [==============================] - 9s 5s/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 1.1740 - val_accuracy: 0.6167
# Epoch 56/300
# 2/2 [==============================] - 9s 5s/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 1.1766 - val_accuracy: 0.6167
# Epoch 57/300
# 2/2 [==============================] - 12s 6s/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 1.1790 - val_accuracy: 0.6167
# Epoch 58/300
# 2/2 [==============================] - 9s 5s/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 1.1836 - val_accuracy: 0.6167
# Epoch 59/300
# 2/2 [==============================] - 10s 5s/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 1.1861 - val_accuracy: 0.6167
# Epoch 60/300
# 2/2 [==============================] - 10s 5s/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 1.1877 - val_accuracy: 0.6167
# Epoch 61/300
# 2/2 [==============================] - 10s 5s/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 1.1909 - val_accuracy: 0.6167
# Epoch 62/300
# 2/2 [==============================] - 9s 5s/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 1.1949 - val_accuracy: 0.6167
# Epoch 63/300
# 2/2 [==============================] - 10s 5s/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 1.1975 - val_accuracy: 0.6167
# Epoch 64/300
# 2/2 [==============================] - 9s 5s/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 1.2004 - val_accuracy: 0.6167
# Epoch 65/300
# 2/2 [==============================] - 9s 5s/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 1.2014 - val_accuracy: 0.6167
# Epoch 66/300
# 2/2 [==============================] - 9s 5s/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 1.2052 - val_accuracy: 0.6167
# Epoch 67/300
# 2/2 [==============================] - 10s 5s/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 1.2092 - val_accuracy: 0.6167
# Epoch 68/300
# 2/2 [==============================] - 10s 5s/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 1.2110 - val_accuracy: 0.6167
# Epoch 69/300
# 2/2 [==============================] - 11s 5s/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 1.2143 - val_accuracy: 0.6167
# Epoch 70/300
# 2/2 [==============================] - 13s 6s/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 1.2169 - val_accuracy: 0.6167
# Epoch 71/300
# 2/2 [==============================] - 11s 6s/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 1.2184 - val_accuracy: 0.6167
# Epoch 72/300
# 2/2 [==============================] - 11s 6s/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 1.2212 - val_accuracy: 0.6167
# Epoch 73/300
# 2/2 [==============================] - 12s 6s/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 1.2231 - val_accuracy: 0.6167
# Epoch 74/300
# 2/2 [==============================] - 11s 6s/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 1.2257 - val_accuracy: 0.6167
# Epoch 75/300
# 2/2 [==============================] - 11s 5s/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 1.2271 - val_accuracy: 0.6167
# Epoch 76/300
# 2/2 [==============================] - 11s 5s/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 1.2302 - val_accuracy: 0.6000
# Epoch 77/300
# 2/2 [==============================] - 10s 5s/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 1.2318 - val_accuracy: 0.6000
# Epoch 78/300
# 2/2 [==============================] - 11s 5s/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 1.2340 - val_accuracy: 0.6167
# Epoch 79/300
# 2/2 [==============================] - 11s 5s/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.2361 - val_accuracy: 0.6167
# Epoch 80/300
# 2/2 [==============================] - 11s 6s/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.2383 - val_accuracy: 0.6167
# Epoch 81/300
# 2/2 [==============================] - 12s 6s/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.2413 - val_accuracy: 0.6167
# Epoch 82/300
# 2/2 [==============================] - 11s 6s/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 1.2421 - val_accuracy: 0.6000
# Epoch 83/300
# 2/2 [==============================] - 11s 6s/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 1.2434 - val_accuracy: 0.6000
# Epoch 84/300
# 2/2 [==============================] - 10s 5s/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 1.2458 - val_accuracy: 0.6000
# Epoch 85/300
# 2/2 [==============================] - 9s 5s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.2483 - val_accuracy: 0.6000
# Epoch 86/300
# 2/2 [==============================] - 10s 5s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.2516 - val_accuracy: 0.6000
# Epoch 87/300
# 2/2 [==============================] - 10s 5s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.2548 - val_accuracy: 0.6000
# Epoch 88/300
# 2/2 [==============================] - 10s 5s/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 1.2569 - val_accuracy: 0.6167
# Epoch 89/300
# 2/2 [==============================] - 11s 5s/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 1.2610 - val_accuracy: 0.6000
# Epoch 90/300
# 2/2 [==============================] - 11s 5s/step - loss: 9.7340e-04 - accuracy: 1.0000 - val_loss: 1.2629 - val_accuracy: 0.6167
# Epoch 91/300
# 2/2 [==============================] - 11s 5s/step - loss: 9.5001e-04 - accuracy: 1.0000 - val_loss: 1.2687 - val_accuracy: 0.6000
# Epoch 92/300
# 2/2 [==============================] - 11s 5s/step - loss: 9.2271e-04 - accuracy: 1.0000 - val_loss: 1.2709 - val_accuracy: 0.6000
# Epoch 93/300
# 2/2 [==============================] - 12s 6s/step - loss: 8.9339e-04 - accuracy: 1.0000 - val_loss: 1.2740 - val_accuracy: 0.6000
# Epoch 94/300
# 2/2 [==============================] - 10s 5s/step - loss: 8.6563e-04 - accuracy: 1.0000 - val_loss: 1.2799 - val_accuracy: 0.6000
# Epoch 95/300
# 2/2 [==============================] - 10s 5s/step - loss: 8.4462e-04 - accuracy: 1.0000 - val_loss: 1.2784 - val_accuracy: 0.6000
# Epoch 96/300
# 2/2 [==============================] - 10s 5s/step - loss: 8.2160e-04 - accuracy: 1.0000 - val_loss: 1.2822 - val_accuracy: 0.6000
# Epoch 97/300
# 2/2 [==============================] - 11s 5s/step - loss: 7.9337e-04 - accuracy: 1.0000 - val_loss: 1.2915 - val_accuracy: 0.6000
# Epoch 98/300
# 2/2 [==============================] - 10s 5s/step - loss: 7.7341e-04 - accuracy: 1.0000 - val_loss: 1.2951 - val_accuracy: 0.6000
# Epoch 99/300
# 2/2 [==============================] - 10s 5s/step - loss: 7.4888e-04 - accuracy: 1.0000 - val_loss: 1.2948 - val_accuracy: 0.6000
# Epoch 100/300
# 2/2 [==============================] - 10s 5s/step - loss: 7.2559e-04 - accuracy: 1.0000 - val_loss: 1.3018 - val_accuracy: 0.6000
# Epoch 101/300
# 2/2 [==============================] - 11s 5s/step - loss: 7.0717e-04 - accuracy: 1.0000 - val_loss: 1.3016 - val_accuracy: 0.6000
# Epoch 102/300
# 2/2 [==============================] - 10s 5s/step - loss: 6.8351e-04 - accuracy: 1.0000 - val_loss: 1.3035 - val_accuracy: 0.5833
# Epoch 103/300
# 2/2 [==============================] - 10s 5s/step - loss: 6.5601e-04 - accuracy: 1.0000 - val_loss: 1.3061 - val_accuracy: 0.6000
# Epoch 104/300
# 2/2 [==============================] - 10s 5s/step - loss: 6.3113e-04 - accuracy: 1.0000 - val_loss: 1.3076 - val_accuracy: 0.6000
# Epoch 105/300
# 2/2 [==============================] - 12s 6s/step - loss: 6.2473e-04 - accuracy: 1.0000 - val_loss: 1.3108 - val_accuracy: 0.6167
# Epoch 106/300
# 2/2 [==============================] - 10s 5s/step - loss: 6.0582e-04 - accuracy: 1.0000 - val_loss: 1.3108 - val_accuracy: 0.6000
# Epoch 107/300
# 2/2 [==============================] - 11s 5s/step - loss: 5.9250e-04 - accuracy: 1.0000 - val_loss: 1.3129 - val_accuracy: 0.6167
# Epoch 108/300
# 2/2 [==============================] - 11s 5s/step - loss: 5.6466e-04 - accuracy: 1.0000 - val_loss: 1.3159 - val_accuracy: 0.6167
# Epoch 109/300
# 2/2 [==============================] - 11s 5s/step - loss: 5.6584e-04 - accuracy: 1.0000 - val_loss: 1.3165 - val_accuracy: 0.6167
# Epoch 110/300
# 2/2 [==============================] - 10s 5s/step - loss: 5.3176e-04 - accuracy: 1.0000 - val_loss: 1.3190 - val_accuracy: 0.6167
# Epoch 111/300
# 2/2 [==============================] - 10s 5s/step - loss: 5.1445e-04 - accuracy: 1.0000 - val_loss: 1.3214 - val_accuracy: 0.6167
# Epoch 112/300
# 2/2 [==============================] - 10s 5s/step - loss: 5.0217e-04 - accuracy: 1.0000 - val_loss: 1.3252 - val_accuracy: 0.6333
# Epoch 113/300
# 2/2 [==============================] - 10s 5s/step - loss: 4.9052e-04 - accuracy: 1.0000 - val_loss: 1.3272 - val_accuracy: 0.6167
# Epoch 114/300
# 2/2 [==============================] - 10s 5s/step - loss: 4.7065e-04 - accuracy: 1.0000 - val_loss: 1.3294 - val_accuracy: 0.6167
# Epoch 115/300
# 2/2 [==============================] - 10s 5s/step - loss: 4.6499e-04 - accuracy: 1.0000 - val_loss: 1.3292 - val_accuracy: 0.6167
# Epoch 116/300
# 2/2 [==============================] - 10s 5s/step - loss: 4.4537e-04 - accuracy: 1.0000 - val_loss: 1.3351 - val_accuracy: 0.6333
# Epoch 117/300
# 2/2 [==============================] - 12s 6s/step - loss: 4.3094e-04 - accuracy: 1.0000 - val_loss: 1.3411 - val_accuracy: 0.6333
# Epoch 118/300
# 2/2 [==============================] - 11s 5s/step - loss: 4.2291e-04 - accuracy: 1.0000 - val_loss: 1.3387 - val_accuracy: 0.6167
# Epoch 119/300
# 2/2 [==============================] - 11s 5s/step - loss: 4.1381e-04 - accuracy: 1.0000 - val_loss: 1.3465 - val_accuracy: 0.6333
# Epoch 120/300
# 2/2 [==============================] - 10s 5s/step - loss: 3.9877e-04 - accuracy: 1.0000 - val_loss: 1.3430 - val_accuracy: 0.6167
# Epoch 121/300
# 2/2 [==============================] - 10s 5s/step - loss: 3.9493e-04 - accuracy: 1.0000 - val_loss: 1.3493 - val_accuracy: 0.6333
# Epoch 122/300
# 2/2 [==============================] - 11s 5s/step - loss: 3.7528e-04 - accuracy: 1.0000 - val_loss: 1.3581 - val_accuracy: 0.5667
# Epoch 123/300
# 2/2 [==============================] - 10s 5s/step - loss: 3.6186e-04 - accuracy: 1.0000 - val_loss: 1.3528 - val_accuracy: 0.6167
# Epoch 124/300
# 2/2 [==============================] - 10s 5s/step - loss: 3.4785e-04 - accuracy: 1.0000 - val_loss: 1.3610 - val_accuracy: 0.5833
# Epoch 125/300
# 2/2 [==============================] - 10s 5s/step - loss: 3.5383e-04 - accuracy: 1.0000 - val_loss: 1.3604 - val_accuracy: 0.6167
# Epoch 126/300
# 2/2 [==============================] - 10s 5s/step - loss: 3.2983e-04 - accuracy: 1.0000 - val_loss: 1.3617 - val_accuracy: 0.6333
# Epoch 127/300
# 2/2 [==============================] - 10s 5s/step - loss: 3.2383e-04 - accuracy: 1.0000 - val_loss: 1.3627 - val_accuracy: 0.6167
# Epoch 128/300
# 2/2 [==============================] - 10s 5s/step - loss: 3.1280e-04 - accuracy: 1.0000 - val_loss: 1.3636 - val_accuracy: 0.6333
# Epoch 129/300
# 2/2 [==============================] - 12s 6s/step - loss: 3.0448e-04 - accuracy: 1.0000 - val_loss: 1.3703 - val_accuracy: 0.6167
# Epoch 130/300
# 2/2 [==============================] - 10s 5s/step - loss: 2.9094e-04 - accuracy: 1.0000 - val_loss: 1.3724 - val_accuracy: 0.6167
# Epoch 131/300
# 2/2 [==============================] - 11s 5s/step - loss: 2.8640e-04 - accuracy: 1.0000 - val_loss: 1.3758 - val_accuracy: 0.5833
# Epoch 132/300
# 2/2 [==============================] - 10s 5s/step - loss: 2.7776e-04 - accuracy: 1.0000 - val_loss: 1.3791 - val_accuracy: 0.6000
# Epoch 133/300
# 2/2 [==============================] - 11s 5s/step - loss: 2.7310e-04 - accuracy: 1.0000 - val_loss: 1.3797 - val_accuracy: 0.6000
# Epoch 134/300
# 2/2 [==============================] - 10s 5s/step - loss: 2.6422e-04 - accuracy: 1.0000 - val_loss: 1.3816 - val_accuracy: 0.6000
# Epoch 135/300
# 2/2 [==============================] - 9s 4s/step - loss: 2.5922e-04 - accuracy: 1.0000 - val_loss: 1.3859 - val_accuracy: 0.6000
# Epoch 136/300
# 2/2 [==============================] - 9s 4s/step - loss: 2.5587e-04 - accuracy: 1.0000 - val_loss: 1.3859 - val_accuracy: 0.6000
# Epoch 137/300
# 2/2 [==============================] - 9s 4s/step - loss: 2.4815e-04 - accuracy: 1.0000 - val_loss: 1.3835 - val_accuracy: 0.6167
# Epoch 138/300
# 2/2 [==============================] - 9s 4s/step - loss: 2.4453e-04 - accuracy: 1.0000 - val_loss: 1.3861 - val_accuracy: 0.6000
# Epoch 139/300
# 2/2 [==============================] - 9s 4s/step - loss: 2.3866e-04 - accuracy: 1.0000 - val_loss: 1.3844 - val_accuracy: 0.5833
# Epoch 140/300
# 2/2 [==============================] - 9s 4s/step - loss: 2.3675e-04 - accuracy: 1.0000 - val_loss: 1.3882 - val_accuracy: 0.6000
# Epoch 141/300
# 2/2 [==============================] - 9s 4s/step - loss: 2.2795e-04 - accuracy: 1.0000 - val_loss: 1.3921 - val_accuracy: 0.6000
# Epoch 142/300
# 2/2 [==============================] - 10s 5s/step - loss: 2.2324e-04 - accuracy: 1.0000 - val_loss: 1.3930 - val_accuracy: 0.6000
# Epoch 143/300
# 2/2 [==============================] - 9s 4s/step - loss: 2.1883e-04 - accuracy: 1.0000 - val_loss: 1.3938 - val_accuracy: 0.6000
# Epoch 144/300
# 2/2 [==============================] - 9s 4s/step - loss: 2.1378e-04 - accuracy: 1.0000 - val_loss: 1.3952 - val_accuracy: 0.6000
# Epoch 145/300
# 2/2 [==============================] - 9s 4s/step - loss: 2.1016e-04 - accuracy: 1.0000 - val_loss: 1.3927 - val_accuracy: 0.5667
# Epoch 146/300
# 2/2 [==============================] - 9s 4s/step - loss: 2.0862e-04 - accuracy: 1.0000 - val_loss: 1.3957 - val_accuracy: 0.6000
# Epoch 147/300
# 2/2 [==============================] - 9s 4s/step - loss: 2.0356e-04 - accuracy: 1.0000 - val_loss: 1.3954 - val_accuracy: 0.6000
# Epoch 148/300
# 2/2 [==============================] - 9s 4s/step - loss: 1.9902e-04 - accuracy: 1.0000 - val_loss: 1.3969 - val_accuracy: 0.6000
# Epoch 149/300
# 2/2 [==============================] - 9s 4s/step - loss: 1.9621e-04 - accuracy: 1.0000 - val_loss: 1.3956 - val_accuracy: 0.5833
# Epoch 150/300
# 2/2 [==============================] - 9s 4s/step - loss: 1.9303e-04 - accuracy: 1.0000 - val_loss: 1.3957 - val_accuracy: 0.6000
# Epoch 151/300
# 2/2 [==============================] - 9s 4s/step - loss: 1.9013e-04 - accuracy: 1.0000 - val_loss: 1.3969 - val_accuracy: 0.6000
# Epoch 152/300
# 2/2 [==============================] - 9s 4s/step - loss: 1.8639e-04 - accuracy: 1.0000 - val_loss: 1.3981 - val_accuracy: 0.6000
# Epoch 153/300
# 2/2 [==============================] - 9s 4s/step - loss: 1.8384e-04 - accuracy: 1.0000 - val_loss: 1.3973 - val_accuracy: 0.6000
# Epoch 154/300
# 2/2 [==============================] - 9s 5s/step - loss: 1.8064e-04 - accuracy: 1.0000 - val_loss: 1.3985 - val_accuracy: 0.6000
# Epoch 155/300
# 2/2 [==============================] - 9s 4s/step - loss: 1.7857e-04 - accuracy: 1.0000 - val_loss: 1.4020 - val_accuracy: 0.6000
# Epoch 156/300
# 2/2 [==============================] - 10s 5s/step - loss: 1.7487e-04 - accuracy: 1.0000 - val_loss: 1.4026 - val_accuracy: 0.6000
# Epoch 157/300
# 2/2 [==============================] - 9s 4s/step - loss: 1.7302e-04 - accuracy: 1.0000 - val_loss: 1.4025 - val_accuracy: 0.6000
# Epoch 158/300
# 2/2 [==============================] - 9s 4s/step - loss: 1.7059e-04 - accuracy: 1.0000 - val_loss: 1.4089 - val_accuracy: 0.6000
# Epoch 159/300
# 2/2 [==============================] - 9s 4s/step - loss: 1.6849e-04 - accuracy: 1.0000 - val_loss: 1.4057 - val_accuracy: 0.5833
# Epoch 160/300
# 2/2 [==============================] - 9s 4s/step - loss: 1.6530e-04 - accuracy: 1.0000 - val_loss: 1.4081 - val_accuracy: 0.5833
# Epoch 161/300
# 2/2 [==============================] - 9s 4s/step - loss: 1.6285e-04 - accuracy: 1.0000 - val_loss: 1.4091 - val_accuracy: 0.5833
# Epoch 162/300
# 2/2 [==============================] - 9s 4s/step - loss: 1.6074e-04 - accuracy: 1.0000 - val_loss: 1.4117 - val_accuracy: 0.5833
# Epoch 163/300
# 2/2 [==============================] - 9s 4s/step - loss: 1.5918e-04 - accuracy: 1.0000 - val_loss: 1.4128 - val_accuracy: 0.5833
# Epoch 164/300
# 2/2 [==============================] - 9s 4s/step - loss: 1.5719e-04 - accuracy: 1.0000 - val_loss: 1.4152 - val_accuracy: 0.6000
# Epoch 165/300
# 2/2 [==============================] - 9s 4s/step - loss: 1.5498e-04 - accuracy: 1.0000 - val_loss: 1.4161 - val_accuracy: 0.5833
# Epoch 166/300
# 2/2 [==============================] - 9s 4s/step - loss: 1.5281e-04 - accuracy: 1.0000 - val_loss: 1.4155 - val_accuracy: 0.5833
# Epoch 167/300
# 2/2 [==============================] - 9s 4s/step - loss: 1.5035e-04 - accuracy: 1.0000 - val_loss: 1.4152 - val_accuracy: 0.5833
# Epoch 168/300
# 2/2 [==============================] - 9s 4s/step - loss: 1.4883e-04 - accuracy: 1.0000 - val_loss: 1.4180 - val_accuracy: 0.5833
# Epoch 169/300
# 2/2 [==============================] - 9s 4s/step - loss: 1.4568e-04 - accuracy: 1.0000 - val_loss: 1.4183 - val_accuracy: 0.6000
# Epoch 170/300
# 2/2 [==============================] - 12s 6s/step - loss: 1.4383e-04 - accuracy: 1.0000 - val_loss: 1.4180 - val_accuracy: 0.5833
# Epoch 171/300
# 2/2 [==============================] - 9s 4s/step - loss: 1.4118e-04 - accuracy: 1.0000 - val_loss: 1.4176 - val_accuracy: 0.6000
# Epoch 172/300
# 2/2 [==============================] - 9s 4s/step - loss: 1.3952e-04 - accuracy: 1.0000 - val_loss: 1.4222 - val_accuracy: 0.6000
# Epoch 173/300
# 2/2 [==============================] - 9s 4s/step - loss: 1.3733e-04 - accuracy: 1.0000 - val_loss: 1.4233 - val_accuracy: 0.6000
# Epoch 174/300
# 2/2 [==============================] - 9s 4s/step - loss: 1.3508e-04 - accuracy: 1.0000 - val_loss: 1.4242 - val_accuracy: 0.5833
# Epoch 175/300
# 2/2 [==============================] - 9s 4s/step - loss: 1.3345e-04 - accuracy: 1.0000 - val_loss: 1.4242 - val_accuracy: 0.5833
# Epoch 176/300
# 2/2 [==============================] - 9s 4s/step - loss: 1.3175e-04 - accuracy: 1.0000 - val_loss: 1.4240 - val_accuracy: 0.5833
# Epoch 177/300
# 2/2 [==============================] - 9s 4s/step - loss: 1.3033e-04 - accuracy: 1.0000 - val_loss: 1.4277 - val_accuracy: 0.6000
# Epoch 178/300
# 2/2 [==============================] - 9s 4s/step - loss: 1.2857e-04 - accuracy: 1.0000 - val_loss: 1.4226 - val_accuracy: 0.5833
# Epoch 179/300
# 2/2 [==============================] - 9s 4s/step - loss: 1.2783e-04 - accuracy: 1.0000 - val_loss: 1.4280 - val_accuracy: 0.5833
# Epoch 180/300
# 2/2 [==============================] - 9s 4s/step - loss: 1.2438e-04 - accuracy: 1.0000 - val_loss: 1.4327 - val_accuracy: 0.6000
# Epoch 181/300
# 2/2 [==============================] - 9s 4s/step - loss: 1.2279e-04 - accuracy: 1.0000 - val_loss: 1.4288 - val_accuracy: 0.5833
# Epoch 182/300
# 2/2 [==============================] - 9s 4s/step - loss: 1.2161e-04 - accuracy: 1.0000 - val_loss: 1.4353 - val_accuracy: 0.6000
# Epoch 183/300
# 2/2 [==============================] - 9s 4s/step - loss: 1.1967e-04 - accuracy: 1.0000 - val_loss: 1.4371 - val_accuracy: 0.6000
# Epoch 184/300
# 2/2 [==============================] - 11s 5s/step - loss: 1.1823e-04 - accuracy: 1.0000 - val_loss: 1.4339 - val_accuracy: 0.6000
# Epoch 185/300
# 2/2 [==============================] - 9s 4s/step - loss: 1.1646e-04 - accuracy: 1.0000 - val_loss: 1.4338 - val_accuracy: 0.6000
# Epoch 186/300
# 2/2 [==============================] - 9s 4s/step - loss: 1.1486e-04 - accuracy: 1.0000 - val_loss: 1.4401 - val_accuracy: 0.6000
# Epoch 187/300
# 2/2 [==============================] - 9s 4s/step - loss: 1.1377e-04 - accuracy: 1.0000 - val_loss: 1.4362 - val_accuracy: 0.6000
# Epoch 188/300
# 2/2 [==============================] - 9s 4s/step - loss: 1.1204e-04 - accuracy: 1.0000 - val_loss: 1.4366 - val_accuracy: 0.6000
# Epoch 189/300
# 2/2 [==============================] - 9s 4s/step - loss: 1.1074e-04 - accuracy: 1.0000 - val_loss: 1.4420 - val_accuracy: 0.6000
# Epoch 190/300
# 2/2 [==============================] - 9s 4s/step - loss: 1.0932e-04 - accuracy: 1.0000 - val_loss: 1.4432 - val_accuracy: 0.6000
# Epoch 191/300
# 2/2 [==============================] - 9s 4s/step - loss: 1.0801e-04 - accuracy: 1.0000 - val_loss: 1.4420 - val_accuracy: 0.5833
# Epoch 192/300
# 2/2 [==============================] - 9s 4s/step - loss: 1.0683e-04 - accuracy: 1.0000 - val_loss: 1.4432 - val_accuracy: 0.6000
# Epoch 193/300
# 2/2 [==============================] - 9s 4s/step - loss: 1.0582e-04 - accuracy: 1.0000 - val_loss: 1.4422 - val_accuracy: 0.6000
# Epoch 194/300
# 2/2 [==============================] - 9s 4s/step - loss: 1.0449e-04 - accuracy: 1.0000 - val_loss: 1.4425 - val_accuracy: 0.6000
# Epoch 195/300
# 2/2 [==============================] - 9s 4s/step - loss: 1.0331e-04 - accuracy: 1.0000 - val_loss: 1.4470 - val_accuracy: 0.6000
# Epoch 196/300
# 2/2 [==============================] - 9s 4s/step - loss: 1.0202e-04 - accuracy: 1.0000 - val_loss: 1.4495 - val_accuracy: 0.6000
# Epoch 197/300
# 2/2 [==============================] - 9s 4s/step - loss: 1.0092e-04 - accuracy: 1.0000 - val_loss: 1.4476 - val_accuracy: 0.5833
# Epoch 198/300
# 2/2 [==============================] - 10s 5s/step - loss: 9.9817e-05 - accuracy: 1.0000 - val_loss: 1.4484 - val_accuracy: 0.5833
# Epoch 199/300
# 2/2 [==============================] - 9s 4s/step - loss: 9.8960e-05 - accuracy: 1.0000 - val_loss: 1.4490 - val_accuracy: 0.5833
# Epoch 200/300
# 2/2 [==============================] - 9s 4s/step - loss: 9.7690e-05 - accuracy: 1.0000 - val_loss: 1.4505 - val_accuracy: 0.5833
# Epoch 201/300
# 2/2 [==============================] - 9s 4s/step - loss: 9.6705e-05 - accuracy: 1.0000 - val_loss: 1.4507 - val_accuracy: 0.5833
# Epoch 202/300
# 2/2 [==============================] - 9s 4s/step - loss: 9.5804e-05 - accuracy: 1.0000 - val_loss: 1.4502 - val_accuracy: 0.5833
# Epoch 203/300
# 2/2 [==============================] - 9s 4s/step - loss: 9.4854e-05 - accuracy: 1.0000 - val_loss: 1.4561 - val_accuracy: 0.6000
# Epoch 204/300
# 2/2 [==============================] - 9s 4s/step - loss: 9.3779e-05 - accuracy: 1.0000 - val_loss: 1.4548 - val_accuracy: 0.5833
# Epoch 205/300
# 2/2 [==============================] - 9s 4s/step - loss: 9.2967e-05 - accuracy: 1.0000 - val_loss: 1.4540 - val_accuracy: 0.5833
# Epoch 206/300
# 2/2 [==============================] - 9s 4s/step - loss: 9.1960e-05 - accuracy: 1.0000 - val_loss: 1.4562 - val_accuracy: 0.5833
# Epoch 207/300
# 2/2 [==============================] - 9s 4s/step - loss: 9.0893e-05 - accuracy: 1.0000 - val_loss: 1.4567 - val_accuracy: 0.5833
# Epoch 208/300
# 2/2 [==============================] - 9s 4s/step - loss: 9.0104e-05 - accuracy: 1.0000 - val_loss: 1.4590 - val_accuracy: 0.5833
# Epoch 209/300
# 2/2 [==============================] - 9s 4s/step - loss: 8.9296e-05 - accuracy: 1.0000 - val_loss: 1.4651 - val_accuracy: 0.6000
# Epoch 210/300
# 2/2 [==============================] - 9s 4s/step - loss: 8.8710e-05 - accuracy: 1.0000 - val_loss: 1.4612 - val_accuracy: 0.5833
# Epoch 211/300
# 2/2 [==============================] - 9s 4s/step - loss: 8.7411e-05 - accuracy: 1.0000 - val_loss: 1.4644 - val_accuracy: 0.5833
# Epoch 212/300
# 2/2 [==============================] - 9s 4s/step - loss: 8.6674e-05 - accuracy: 1.0000 - val_loss: 1.4632 - val_accuracy: 0.5833
# Epoch 213/300
# 2/2 [==============================] - 10s 5s/step - loss: 8.5974e-05 - accuracy: 1.0000 - val_loss: 1.4634 - val_accuracy: 0.5833
# Epoch 214/300
# 2/2 [==============================] - 9s 4s/step - loss: 8.5168e-05 - accuracy: 1.0000 - val_loss: 1.4653 - val_accuracy: 0.5833
# Epoch 215/300
# 2/2 [==============================] - 9s 4s/step - loss: 8.4293e-05 - accuracy: 1.0000 - val_loss: 1.4664 - val_accuracy: 0.5833
# Epoch 216/300
# 2/2 [==============================] - 9s 4s/step - loss: 8.3575e-05 - accuracy: 1.0000 - val_loss: 1.4666 - val_accuracy: 0.5833
# Epoch 217/300
# 2/2 [==============================] - 9s 4s/step - loss: 8.2690e-05 - accuracy: 1.0000 - val_loss: 1.4684 - val_accuracy: 0.5833
# Epoch 218/300
# 2/2 [==============================] - 9s 4s/step - loss: 8.2037e-05 - accuracy: 1.0000 - val_loss: 1.4741 - val_accuracy: 0.5833
# Epoch 219/300
# 2/2 [==============================] - 9s 4s/step - loss: 8.1375e-05 - accuracy: 1.0000 - val_loss: 1.4722 - val_accuracy: 0.5833
# Epoch 220/300
# 2/2 [==============================] - 9s 4s/step - loss: 8.0571e-05 - accuracy: 1.0000 - val_loss: 1.4725 - val_accuracy: 0.5833
# Epoch 221/300
# 2/2 [==============================] - 9s 4s/step - loss: 7.9903e-05 - accuracy: 1.0000 - val_loss: 1.4727 - val_accuracy: 0.5833
# Epoch 222/300
# 2/2 [==============================] - 9s 4s/step - loss: 7.9155e-05 - accuracy: 1.0000 - val_loss: 1.4730 - val_accuracy: 0.5833
# Epoch 223/300
# 2/2 [==============================] - 9s 4s/step - loss: 7.8497e-05 - accuracy: 1.0000 - val_loss: 1.4781 - val_accuracy: 0.5833
# Epoch 224/300
# 2/2 [==============================] - 9s 4s/step - loss: 7.7830e-05 - accuracy: 1.0000 - val_loss: 1.4749 - val_accuracy: 0.5833
# Epoch 225/300
# 2/2 [==============================] - 9s 4s/step - loss: 7.7160e-05 - accuracy: 1.0000 - val_loss: 1.4779 - val_accuracy: 0.5833
# Epoch 226/300
# 2/2 [==============================] - 9s 4s/step - loss: 7.6396e-05 - accuracy: 1.0000 - val_loss: 1.4791 - val_accuracy: 0.5833
# Epoch 227/300
# 2/2 [==============================] - 10s 5s/step - loss: 7.5705e-05 - accuracy: 1.0000 - val_loss: 1.4799 - val_accuracy: 0.5833
# Epoch 228/300
# 2/2 [==============================] - 9s 4s/step - loss: 7.5040e-05 - accuracy: 1.0000 - val_loss: 1.4792 - val_accuracy: 0.5833
# Epoch 229/300
# 2/2 [==============================] - 9s 4s/step - loss: 7.4418e-05 - accuracy: 1.0000 - val_loss: 1.4814 - val_accuracy: 0.5833
# Epoch 230/300
# 2/2 [==============================] - 9s 4s/step - loss: 7.3775e-05 - accuracy: 1.0000 - val_loss: 1.4810 - val_accuracy: 0.5833
# Epoch 231/300
# 2/2 [==============================] - 9s 4s/step - loss: 7.3186e-05 - accuracy: 1.0000 - val_loss: 1.4824 - val_accuracy: 0.5833
# Epoch 232/300
# 2/2 [==============================] - 9s 4s/step - loss: 7.2546e-05 - accuracy: 1.0000 - val_loss: 1.4838 - val_accuracy: 0.5833
# Epoch 233/300
# 2/2 [==============================] - 9s 4s/step - loss: 7.2151e-05 - accuracy: 1.0000 - val_loss: 1.4883 - val_accuracy: 0.5833
# Epoch 234/300
# 2/2 [==============================] - 9s 4s/step - loss: 7.1421e-05 - accuracy: 1.0000 - val_loss: 1.4878 - val_accuracy: 0.5833
# Epoch 235/300
# 2/2 [==============================] - 9s 4s/step - loss: 7.0873e-05 - accuracy: 1.0000 - val_loss: 1.4872 - val_accuracy: 0.5833
# Epoch 236/300
# 2/2 [==============================] - 9s 4s/step - loss: 7.0258e-05 - accuracy: 1.0000 - val_loss: 1.4889 - val_accuracy: 0.5833
# Epoch 237/300
# 2/2 [==============================] - 9s 4s/step - loss: 6.9608e-05 - accuracy: 1.0000 - val_loss: 1.4898 - val_accuracy: 0.5833
# Epoch 238/300
# 2/2 [==============================] - 9s 4s/step - loss: 6.9066e-05 - accuracy: 1.0000 - val_loss: 1.4899 - val_accuracy: 0.5833
# Epoch 239/300
# 2/2 [==============================] - 9s 4s/step - loss: 6.8547e-05 - accuracy: 1.0000 - val_loss: 1.4955 - val_accuracy: 0.5833
# Epoch 240/300
# 2/2 [==============================] - 9s 4s/step - loss: 6.8133e-05 - accuracy: 1.0000 - val_loss: 1.4935 - val_accuracy: 0.5833
# Epoch 241/300
# 2/2 [==============================] - 11s 6s/step - loss: 6.7470e-05 - accuracy: 1.0000 - val_loss: 1.4945 - val_accuracy: 0.5833
# Epoch 242/300
# 2/2 [==============================] - 9s 4s/step - loss: 6.6999e-05 - accuracy: 1.0000 - val_loss: 1.4950 - val_accuracy: 0.5833
# Epoch 243/300
# 2/2 [==============================] - 9s 4s/step - loss: 6.6531e-05 - accuracy: 1.0000 - val_loss: 1.4949 - val_accuracy: 0.5833
# Epoch 244/300
# 2/2 [==============================] - 9s 4s/step - loss: 6.5883e-05 - accuracy: 1.0000 - val_loss: 1.4959 - val_accuracy: 0.5833
# Epoch 245/300
# 2/2 [==============================] - 9s 4s/step - loss: 6.5352e-05 - accuracy: 1.0000 - val_loss: 1.4986 - val_accuracy: 0.5833
# Epoch 246/300
# 2/2 [==============================] - 9s 4s/step - loss: 6.4892e-05 - accuracy: 1.0000 - val_loss: 1.4991 - val_accuracy: 0.5833
# Epoch 247/300
# 2/2 [==============================] - 9s 4s/step - loss: 6.4438e-05 - accuracy: 1.0000 - val_loss: 1.4987 - val_accuracy: 0.5833
# Epoch 248/300
# 2/2 [==============================] - 9s 4s/step - loss: 6.3847e-05 - accuracy: 1.0000 - val_loss: 1.4991 - val_accuracy: 0.5833
# Epoch 249/300
# 2/2 [==============================] - 9s 4s/step - loss: 6.3394e-05 - accuracy: 1.0000 - val_loss: 1.4980 - val_accuracy: 0.5833
# Epoch 250/300
# 2/2 [==============================] - 9s 4s/step - loss: 6.3116e-05 - accuracy: 1.0000 - val_loss: 1.5024 - val_accuracy: 0.5833
# Epoch 251/300
# 2/2 [==============================] - 9s 4s/step - loss: 6.2427e-05 - accuracy: 1.0000 - val_loss: 1.5072 - val_accuracy: 0.5833
# Epoch 252/300
# 2/2 [==============================] - 9s 4s/step - loss: 6.2115e-05 - accuracy: 1.0000 - val_loss: 1.5050 - val_accuracy: 0.5833
# Epoch 253/300
# 2/2 [==============================] - 9s 4s/step - loss: 6.1506e-05 - accuracy: 1.0000 - val_loss: 1.5058 - val_accuracy: 0.5833
# Epoch 254/300
# 2/2 [==============================] - 9s 4s/step - loss: 6.1103e-05 - accuracy: 1.0000 - val_loss: 1.5067 - val_accuracy: 0.5833
# Epoch 255/300
# 2/2 [==============================] - 13s 7s/step - loss: 6.0631e-05 - accuracy: 1.0000 - val_loss: 1.5085 - val_accuracy: 0.5833
# Epoch 256/300
# 2/2 [==============================] - 9s 4s/step - loss: 6.0244e-05 - accuracy: 1.0000 - val_loss: 1.5089 - val_accuracy: 0.5833
# Epoch 257/300
# 2/2 [==============================] - 9s 4s/step - loss: 5.9745e-05 - accuracy: 1.0000 - val_loss: 1.5103 - val_accuracy: 0.5833
# Epoch 258/300
# 2/2 [==============================] - 9s 4s/step - loss: 5.9350e-05 - accuracy: 1.0000 - val_loss: 1.5102 - val_accuracy: 0.5833
# Epoch 259/300
# 2/2 [==============================] - 9s 4s/step - loss: 5.8880e-05 - accuracy: 1.0000 - val_loss: 1.5121 - val_accuracy: 0.5833
# Epoch 260/300
# 2/2 [==============================] - 9s 4s/step - loss: 5.8493e-05 - accuracy: 1.0000 - val_loss: 1.5116 - val_accuracy: 0.5833
# Epoch 261/300
# 2/2 [==============================] - 9s 4s/step - loss: 5.8087e-05 - accuracy: 1.0000 - val_loss: 1.5123 - val_accuracy: 0.5833
# Epoch 262/300
# 2/2 [==============================] - 9s 4s/step - loss: 5.7607e-05 - accuracy: 1.0000 - val_loss: 1.5120 - val_accuracy: 0.5833
# Epoch 263/300
# 2/2 [==============================] - 9s 4s/step - loss: 5.7261e-05 - accuracy: 1.0000 - val_loss: 1.5172 - val_accuracy: 0.5833
# Epoch 264/300
# 2/2 [==============================] - 9s 4s/step - loss: 5.6867e-05 - accuracy: 1.0000 - val_loss: 1.5161 - val_accuracy: 0.5833
# Epoch 265/300
# 2/2 [==============================] - 9s 4s/step - loss: 5.6448e-05 - accuracy: 1.0000 - val_loss: 1.5172 - val_accuracy: 0.5833
# Epoch 266/300
# 2/2 [==============================] - 9s 4s/step - loss: 5.5990e-05 - accuracy: 1.0000 - val_loss: 1.5178 - val_accuracy: 0.5833
# Epoch 267/300
# 2/2 [==============================] - 9s 4s/step - loss: 5.5637e-05 - accuracy: 1.0000 - val_loss: 1.5188 - val_accuracy: 0.5833
# Epoch 268/300
# 2/2 [==============================] - 9s 4s/step - loss: 5.5204e-05 - accuracy: 1.0000 - val_loss: 1.5199 - val_accuracy: 0.5833
# Epoch 269/300
# 2/2 [==============================] - 10s 5s/step - loss: 5.4867e-05 - accuracy: 1.0000 - val_loss: 1.5207 - val_accuracy: 0.5833
# Epoch 270/300
# 2/2 [==============================] - 9s 4s/step - loss: 5.4453e-05 - accuracy: 1.0000 - val_loss: 1.5212 - val_accuracy: 0.5833
# Epoch 271/300
# 2/2 [==============================] - 9s 4s/step - loss: 5.4112e-05 - accuracy: 1.0000 - val_loss: 1.5231 - val_accuracy: 0.5833
# Epoch 272/300
# 2/2 [==============================] - 9s 4s/step - loss: 5.3702e-05 - accuracy: 1.0000 - val_loss: 1.5232 - val_accuracy: 0.5833
# Epoch 273/300
# 2/2 [==============================] - 9s 4s/step - loss: 5.3519e-05 - accuracy: 1.0000 - val_loss: 1.5243 - val_accuracy: 0.5833
# Epoch 274/300
# 2/2 [==============================] - 9s 4s/step - loss: 5.3035e-05 - accuracy: 1.0000 - val_loss: 1.5255 - val_accuracy: 0.5833
# Epoch 275/300
# 2/2 [==============================] - 9s 4s/step - loss: 5.2736e-05 - accuracy: 1.0000 - val_loss: 1.5258 - val_accuracy: 0.5833
# Epoch 276/300
# 2/2 [==============================] - 9s 4s/step - loss: 5.2298e-05 - accuracy: 1.0000 - val_loss: 1.5267 - val_accuracy: 0.5833
# Epoch 277/300
# 2/2 [==============================] - 9s 4s/step - loss: 5.1992e-05 - accuracy: 1.0000 - val_loss: 1.5274 - val_accuracy: 0.5833
# Epoch 278/300
# 2/2 [==============================] - 9s 4s/step - loss: 5.1626e-05 - accuracy: 1.0000 - val_loss: 1.5303 - val_accuracy: 0.5833
# Epoch 279/300
# 2/2 [==============================] - 9s 4s/step - loss: 5.1260e-05 - accuracy: 1.0000 - val_loss: 1.5295 - val_accuracy: 0.5833
# Epoch 280/300
# 2/2 [==============================] - 9s 4s/step - loss: 5.0953e-05 - accuracy: 1.0000 - val_loss: 1.5311 - val_accuracy: 0.5833
# Epoch 281/300
# 2/2 [==============================] - 9s 4s/step - loss: 5.0650e-05 - accuracy: 1.0000 - val_loss: 1.5322 - val_accuracy: 0.5833
# Epoch 282/300
# 2/2 [==============================] - 9s 4s/step - loss: 5.0389e-05 - accuracy: 1.0000 - val_loss: 1.5325 - val_accuracy: 0.5833
# Epoch 283/300
# 2/2 [==============================] - 11s 5s/step - loss: 4.9967e-05 - accuracy: 1.0000 - val_loss: 1.5331 - val_accuracy: 0.5833
# Epoch 284/300
# 2/2 [==============================] - 9s 4s/step - loss: 4.9615e-05 - accuracy: 1.0000 - val_loss: 1.5334 - val_accuracy: 0.5833
# Epoch 285/300
# 2/2 [==============================] - 9s 4s/step - loss: 4.9317e-05 - accuracy: 1.0000 - val_loss: 1.5359 - val_accuracy: 0.5833
# Epoch 286/300
# 2/2 [==============================] - 9s 4s/step - loss: 4.9019e-05 - accuracy: 1.0000 - val_loss: 1.5362 - val_accuracy: 0.5833
# Epoch 287/300
# 2/2 [==============================] - 9s 4s/step - loss: 4.8760e-05 - accuracy: 1.0000 - val_loss: 1.5368 - val_accuracy: 0.5833
# Epoch 288/300
# 2/2 [==============================] - 9s 4s/step - loss: 4.8372e-05 - accuracy: 1.0000 - val_loss: 1.5370 - val_accuracy: 0.5833
# Epoch 289/300
# 2/2 [==============================] - 9s 4s/step - loss: 4.8106e-05 - accuracy: 1.0000 - val_loss: 1.5375 - val_accuracy: 0.5833
# Epoch 290/300
# 2/2 [==============================] - 9s 4s/step - loss: 4.7757e-05 - accuracy: 1.0000 - val_loss: 1.5390 - val_accuracy: 0.5833
# Epoch 291/300
# 2/2 [==============================] - 9s 5s/step - loss: 4.7444e-05 - accuracy: 1.0000 - val_loss: 1.5389 - val_accuracy: 0.5833
# Epoch 292/300
# 2/2 [==============================] - 9s 5s/step - loss: 4.7189e-05 - accuracy: 1.0000 - val_loss: 1.5394 - val_accuracy: 0.5833
# Epoch 293/300
# 2/2 [==============================] - 9s 5s/step - loss: 4.6855e-05 - accuracy: 1.0000 - val_loss: 1.5403 - val_accuracy: 0.5833
# Epoch 294/300
# 2/2 [==============================] - 9s 5s/step - loss: 4.6644e-05 - accuracy: 1.0000 - val_loss: 1.5436 - val_accuracy: 0.5833
# Epoch 295/300
# 2/2 [==============================] - 10s 5s/step - loss: 4.6297e-05 - accuracy: 1.0000 - val_loss: 1.5430 - val_accuracy: 0.5833
# Epoch 296/300
# 2/2 [==============================] - 10s 5s/step - loss: 4.6043e-05 - accuracy: 1.0000 - val_loss: 1.5441 - val_accuracy: 0.5833
# Epoch 297/300
# 2/2 [==============================] - 10s 5s/step - loss: 4.5705e-05 - accuracy: 1.0000 - val_loss: 1.5453 - val_accuracy: 0.5833
# Epoch 298/300
# 2/2 [==============================] - 10s 5s/step - loss: 4.5444e-05 - accuracy: 1.0000 - val_loss: 1.5455 - val_accuracy: 0.5833
# Epoch 299/300
# 2/2 [==============================] - 10s 5s/step - loss: 4.5145e-05 - accuracy: 1.0000 - val_loss: 1.5490 - val_accuracy: 0.5833
# Epoch 300/300
# 2/2 [==============================] - 10s 5s/step - loss: 4.4928e-05 - accuracy: 1.0000 - val_loss: 1.5475 - val_accuracy: 0.5833

# %% [markdown]
# ## Model Evaluation

# %% [markdown]
# Visualize training and validation accuracy/loss

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(300)

plt.figure(figsize=(15, 6))
plt.subplot(1, 2,1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
print('Average training accuracy : ', statistics.mean(history.history['accuracy']))
print('Average validation accuracy : ', statistics.mean(history.history['val_accuracy']), '\n')

print('Average training loss : ', statistics.mean(history.history['loss']))
print('Average validation loss : ', statistics.mean(history.history['val_loss']))
# Out:
# Average training accuracy :  0.9854583
# Average validation accuracy :  0.5948333
#
# Average training loss :  0.18273056003539062
# Average validation loss :  1.3833704330523808

# %% [markdown]
# Visualize classifications example

# %%
fig = plt.figure(figsize=(15,10))
fig.suptitle("Classifications Example of CNN Model", fontsize=16)

predictions = classifier.predict(test_data)
predictions = np.argmax(predictions, axis=1)

for i in range(12):
    number = randint(0, len(predictions))
    plt.subplot(3,4,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.title(test_label_names[number])
    plt.imshow(test_data[number], cmap=plt.cm.binary)
    if test_label_names[number] == label_categories[predictions[number]]:
        plt.xlabel(label_categories[predictions[number]], color='green')
    else:
        plt.xlabel(label_categories[predictions[number]], color='red')
plt.show()

# %% [markdown]
# # Final words

# %% [markdown]
# **Data :**
#
# The data consist of 300 images : 100 images each for Daisy, Rose and Tulip
#
# 300 images randomly divided into 240 images for training and 60 images for testing
#
# **Architecture and Evaluation:**
#
# A Multilayer Perceptron (MLP) model with 1 hidden layer architecture produces a faster classification result with ~51% accuracy for training and ~37% accuracy for testing, ~1.0 loss for both training and ~1.1 loss for testing.
#
# Convolutional Neural Network (CNN) model with 1 pair of Conv-Pool layers and 1 hidden layer architecture produces a longer classification result with ~98% accuracy for training and ~59% accuracy for validation, ~0.2 loss for training and ~1.4 loss for validation.
#
# **Conclusion :**
#
# MLPs use one perceptron for each input (e.g pixel) and the amount of weights rapidly becomes unmanageable for large images. One of the common problems is that MLPs react differently to an input (images) and its shifted version. For example in this data, the flower is not always in the same position on every image and MLPs will try to correct itself and assume that the objects will always appear in certain sections of the image. In this MLPs model architecture, both loss and accuracy are fluctuating as the model seems to be confused on what makes which images belong to which flower class, since MLP doesn't have feature extraction layer(s).
#
# This CNN architecture successfully distinguishes the training images well (too well), but cannot generalize well in the validation images. Overfitting happens in the CNN architecture because the amount of data is too small (only 300 data in total), there are no image augmentation and dropout layer(s) or regularization(L1/L2) applied in this CNN architecture model.
#
# Configuring a deeper layer in CNN model architecture with more than one Conv-Pool layers, applying image augmentation, using dropout layer(s), and feeding more training data will probably increase the accuracy and also avoid overfitting.
